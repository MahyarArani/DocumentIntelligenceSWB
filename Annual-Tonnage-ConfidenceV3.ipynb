# %%
from azure.core.credentials import AzureKeyCredential
from azure.ai.formrecognizer import DocumentAnalysisClient
import os
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import json

# %%
input_folder_path = "New files"
output_folder_path = "ParsedJson"

# %%
# Connection to the document recognizer we trained on Azure
with open ('Config.json', 'r') as json_file:
    data = json.load(json_file)
    endpoint = data["endpoint"]
    key = data["key"]

model_id = "Annual-Tonnage-Feb16-Signature"
document_analysis_client = DocumentAnalysisClient(endpoint=endpoint, credential=AzureKeyCredential(key))

# %%
for filename in os.listdir(input_folder_path):
    if filename.endswith(".pdf"):
        file_path = os.path.join(input_folder_path, filename)
        with open(file_path, "rb") as document:
            print(f"-------->Parsing {filename}<---------")
            content = document.read()
            try:
                poller = document_analysis_client.begin_analyze_document(model_id=model_id, document=content)
                result = poller.result()
                data = result.to_dict()
                output_path = os.path.join(output_folder_path, f"{os.path.splitext(filename)[0]}")
                with open(output_path + '.json', 'w') as json_file:
                    json.dump(data, json_file, indent=4)
            except Exception as e:
                print(f"Error processing file {filename}: {str(e)}")
                continue

# %% [markdown]
# ## Folder Json

# %% [markdown]
# ### Section A

# %%
data_list_A = []

for filename in os.listdir(output_folder_path):
    if filename.endswith(".json"):
        file = os.path.join(output_folder_path, filename)

        with open(file, "r") as json_file:
            print(f"-------->Reading {filename}<---------")
            json_data = json.load(json_file)

            style_list = json_data.get("styles", [])
            handwritten = {}  
            for style in style_list:
                if style.get("is_handwritten", False):  
                    handwritten["Handwritten?"] = "True"
                else:
                    handwritten["Handwritten?"] = "False"

            documents_list = json_data.get("documents", [])
            for document in documents_list:
                field_data_A = {"Filename": filename}
                for name, field in document.get("fields", {}).items():
                    field_value_A = field.get("valueString", "") if field.get("valueString", "") else field.get("content", "")
                    field_data_A[name] = field_value_A
                field_data_A.update(handwritten) 
                data_list_A.append(field_data_A)

headers_A = [
    'Filename',
    'Company',
    'Contact Person',
    'Title',
    'Address',
    'City',
    'State',
    'Zip Code',
    'Phone',
    'Fax',
    'Email',
    'Paper Collection',
    'Electronics Recycling',
    'Secure Document Destruction',
    'Tire Recycling',
    'Solvents/Oil/Antifreeze Recycling',
    'Metals Recycling (Ferrous & Non-Ferrous)',
    'Battery Recycling',
    'Yard Maintenance/Landscaping',
    'Textile, Shoes, and/or Clothing Recycling',
    'Commercial Back-Hauling for Cardboard and Other',
    'Materials Collection (grocery and other retail outlets)',
    'Solid Waste Collection (trash and recycling)',
    'Construction and Demolition Debris Collection',
    'Bulk Waste & Junk Collection',
    'Material Recovery Facility (MRF)',
    'Other',
    'Other-Text',
    'Printed Signature',
    'Signed Date',
    'Methodology',
    'Comments',
    'Handwritten?'
]

df_A = pd.DataFrame(data_list_A, columns=headers_A)
df_A['Phone'] = df_A['Phone'].str.replace(r'[^0-9]', '', regex=True)
df_A['Fax'] = df_A['Fax'].str.replace(r'[^0-9]', '', regex=True)
df_A['City'] = df_A['City'].str.replace(r'[^a-zA-Z]', '', regex=True)
df_A.replace('', "NULL", inplace=True)
df_A.replace(pd.NA, "NULL", inplace=True)

df_A.head(50)
# Out:
# -------->Reading 2023 Annual Tonnage Report ACE.json<---------
# -------->Reading 2023 Annual Tonnage Report Chapel Valley.json<---------
# -------->Reading 2023 Annual Tonnage Report Zero Waste Solutions.json<---------
# -------->Reading 2023 Arlington Annual Tonnage Report-United Rentals.json<---------
# -------->Reading 2023 Arlington Annual Tonnage Report.json<---------
# -------->Reading 2023 Glenayr Apartments Tonnage Report.json<---------
# -------->Reading 2023 Tonnage Report - Bartlett Tree.json<---------
# -------->Reading ADS 2023 Tonnage Report.json<---------
# -------->Reading Atlantic Biofuels Tonnage Report.json<---------
# -------->Reading Capitol Services Tonnage Report 2024 Arlington County.json<---------
# -------->Reading Compost Crew Annual Tonnage Report Arlingon.json<---------
# -------->Reading Concrete Protection and Restoration 2023 Tonnage Report.json<---------
# -------->Reading Darling Ingredients Tonnage Report.json<---------
# -------->Reading Dittmar 2023 Annual Tonnage Report.json<---------
# -------->Reading DMV Hauling Tonnage Report.json<---------
# -------->Reading EAI Arlington Tonnage Report 2024.json<---------
# -------->Reading Environmental Enhancements 2023 Annual Tonnage Report.json<---------
# -------->Reading function enterprises.json<---------
# -------->Reading georgetown paper stock tonnage report.json<---------
# -------->Reading Industrial Disposal Arlington Recycling report 2023.json<---------
# -------->Reading kmG Tonnage Report.json<---------
# -------->Reading Lancaster Landscapes Tonnage Report.json<---------
# -------->Reading Lorco Annual Tonnage Report (Signed).json<---------
# -------->Reading Metal Pro Tonnage Report.json<---------
# -------->Reading Olivo 2023 Annual Tonnage Report.json<---------
# -------->Reading Patriot Disposal Arlington County Tonnage Report 2023.json<---------
# -------->Reading Redbox 2023 Annual Tonnage Report (005).json<---------
# -------->Reading Republic Arlington County Recycling & Refuse Tonnage Report CY 2023.json<---------
# -------->Reading RTI 2023 Annual Tonnage Report.json<---------
# -------->Reading Safeguard Shredding Tonnage Report.json<---------
# -------->Reading Safety kleen Systems Tonnage Report.json<---------
# -------->Reading Selective Demolition Tonnage Report.json<---------
# -------->Reading Selective Hauling Tonnage Report.json<---------
# -------->Reading Six Nations 2023 Annual Tonnage Report.json<---------
# -------->Reading Thompson Hauling Tonnage Report.json<---------
# -------->Reading Trash Away Tonnage Report.json<---------
# -------->Reading Washington and Lee Apartments Tonnage Report.json<---------
# -------->Reading Waste Management Arlington 2023 Tonnage Report.json<---------
#                                              Filename  \
# 0                 2023 Annual Tonnage Report ACE.json
# 1       2023 Annual Tonnage Report Chapel Valley.json
# 2   2023 Annual Tonnage Report Zero Waste Solution...
# 3   2023 Arlington Annual Tonnage Report-United Re...
# 4           2023 Arlington Annual Tonnage Report.json
# 5         2023 Glenayr Apartments Tonnage Report.json
# 6            2023 Tonnage Report - Bartlett Tree.json
# 7                        ADS 2023 Tonnage Report.json
# 8               Atlantic Biofuels Tonnage Report.json
# 9   Capitol Services Tonnage Report 2024 Arlington...
# 10   Compost Crew Annual Tonnage Report Arlingon.json
# 11  Concrete Protection and Restoration 2023 Tonna...
# 12            Darling Ingredients Tonnage Report.json
# 13            Dittmar 2023 Annual Tonnage Report.json
# 14                    DMV Hauling Tonnage Report.json
# 15             EAI Arlington Tonnage Report 2024.json
# 16  Environmental Enhancements 2023 Annual Tonnage...
# 17                          function enterprises.json
# 18         georgetown paper stock tonnage report.json
# 19  Industrial Disposal Arlington Recycling report...
# 20                            kmG Tonnage Report.json
# 21           Lancaster Landscapes Tonnage Report.json
# 22          Lorco Annual Tonnage Report (Signed).json
# 23                      Metal Pro Tonnage Report.json
# 24              Olivo 2023 Annual Tonnage Report.json
# 25  Patriot Disposal Arlington County Tonnage Repo...
# 26       Redbox 2023 Annual Tonnage Report (005).json
# 27  Republic Arlington County Recycling & Refuse T...
# 28                RTI 2023 Annual Tonnage Report.json
# 29            Safeguard Shredding Tonnage Report.json
# 30           Safety kleen Systems Tonnage Report.json
# 31           Selective Demolition Tonnage Report.json
# 32              Selective Hauling Tonnage Report.json
# 33        Six Nations 2023 Annual Tonnage Report.json
# 34               Thompson Hauling Tonnage Report.json
# 35                     Trash Away Tonnage Report.json
# 36  Washington and Lee Apartments Tonnage Report.json
# 37  Waste Management Arlington 2023 Tonnage Report...
#
#                                               Company  \
# 0                              Ace Deconstruction LLC
# 1                     Chapel Valley Landscape Company
# 2                          ZERO WASTE SOLUTIONS, INC.
# 3   United Rentals (North America), Inc .; DBA Rel...
# 4                Brandon Rushing Lawn and Garden Care
# 5                              Glenayr Apartments LLC
# 6                              BARTLETT TREEE EXPERTS
# 7                     American Disposal Services Inc.
# 8                                   Atlantic Biofuels
# 9                   CAPITOL SERVICES OF VIRGINIA INC.
# 10           Compost Crew Inc., A Benefit Corporation
# 11                  Concrete Protection & Restoration
# 12                            Darling Ingredients Inc
# 13                                    DITTMAR COMPANY
# 14                           DMV HAULING SERVICE, LLC
# 15                    Environmental Alternatives, LLC
# 16                         Environmental Enhancements
# 17                          Function Enterprises Inc.
# 18          Georgetown Paper Stock of Rockville, Inc.
# 19                       Industrial Disposal Services
# 20                                  kmG Hauling, Inc.
# 21                               Lancaster Landscapes
# 22                             LORCO OF MARYLAND, LLC
# 23                                      Metalpro, Inc
# 24                           Olivo Trash Service, Inc
# 25                             Patriot Disposal, Inc.
# 26                                               NULL
# 27                 Republic Services of Virginia, LLC
# 28                      Restaurant Technologies, Inc.
# 29  Safeguard Privacy Protection Services Inc DBA ...
# 30         Safety -Kleen Systems, Inc. (Waste Hauler)
# 31                          Selective Demolition, LLC
# 32                             Selective Hauling, LLC
# 33                                    SIX NATIONS INC
# 34                              THOMPSON Hauling, LLC
# 35                                               NULL
# 36                        Washington & Lee Apartments
# 37                                   Waste Management
#
#                                 Contact Person  \
# 0                                 Anchan Ladia
# 1                                JIll Hartkopf
# 2                               JESSICA SEXTON
# 3                               Jeffrey Walker
# 4                               Tamela Addison
# 5                               Arthur E House
# 6                              MARGOT ARELLANO
# 7                                   Kyle Byler
# 8                                   Matt Lopas
# 9                                DAVID J. DUNN
# 10                           Joanne Lesperance
# 11                                  John Moran
# 12                                David Haines
# 13          Juan Nectali Morales\nMario Sancho
# 14                               Leon Hargrove
# 15                                  Mike Ensor
# 16                            Brianna Contessa
# 17                                Brian Martel
# 18                                  Kay Grundy
# 19                             Eric Rotenberry
# 20                               A.J. Costigan
# 21                            adrienne Zaleski
# 22                                  James Kura
# 23                                 Robert Ward
# 24                                   Tim Olivo
# 25                                 Jean Poague
# 26  redbox+ of Northern Virginia\nBrian Bishop
# 27                          Addis Hailegiorgis
# 28                               Jenn Sundberg
# 29                          Gretchen Schofield
# 30                       Simantini Chakraborty
# 31                              Matthew Badeau
# 32                                Carlos Mejia
# 33                                  PAUL DAVIS
# 34                             Eunice Thompson
# 35                                        NULL
# 36                              April Fentress
# 37                         Shawn Jacobs Jordan
#
#                                            Title  \
# 0                                            CFO
# 1                                 Branch Manager
# 2                    ACCOUNTS PAYABLE SPECIALIST
# 3                          Environmental Manager
# 4                           Support Team Manager
# 5                                          Owner
# 6                                LEAD ADMIN ASST
# 7                               District Manager
# 8                                       resident
# 9                                      PRESIDENT
# 10  Supervisor Customer Service / Administration
# 11                                ehouse Manager
# 12                                Office Manager
# 13                                    Supervisor
# 14                            Operations Manager
# 15                         Senior Vice President
# 16                      Administrative Assistant
# 17                                           100
# 18                                    Controller
# 19                            Operations Manager
# 20                                            VP
# 21                                     President
# 22                         Regulatory Compliance
# 23                                     President
# 24                                          Pres
# 25                                Vice President
# 26                                         Owner
# 27                           Division Accountant
# 28           Regulatory and Compliance Associate
# 29                                     Treasurer
# 30            Environmental Compliance Associate
# 31                                Office Manager
# 32                            Operations Manager
# 33                                 VP OPERATIONS
# 34                                       Partner
# 35                                          NULL
# 36                                 Property Mar.
# 37                         Operations Specialist
#
#                                         Address            City State  \
# 0                       13804 Dawson Beach Road      Woodbridge    VA
# 1                            3041 Colvin Street      Alexandria    VA
# 2                                  PO BOX 5097,         CONCORD    CA
# 3                          11825 Livingston Rd,        Manassas   VAS
# 4                         7805 Cinder Bed Road,            NULL  NULL
# 5                  399 N. Park Drive Arlington,            NULL    VA
# 6                     7823 LOISDALE RD, STE LL,     SPRINGFIELD    VA
# 7                         10370 Central Park Dr        Manassas    VA
# 8                         2501 W. Lexington St.       Baltimore    my
# 9                                  P.O. BOX 279      SMITHFIELD   VA.
# 10                        12358 Parklawn Drive,       Rockville    MD
# 11                      2811 Lord Baltimore Dr.       Baltimore    MD
# 12  1635 Indian Hollow Rd. Winchester, VA 22603            NULL  NULL
# 13                           5550 Columbia Pike       Arlington    Va
# 14                                  PO Box 6541      Alexandria    VA
# 15                           24024 Frederick Rd      Clarksburg    MD
# 16                      22311 Shaw Road, Unit C        Sterling    VA
# 17                       7954 Cameron Brown Ct.     Springfield    VA
# 18    14820 Southlawn Lane, Rockville, MD 20850            NULL  NULL
# 19                        9120 Developers Drive        Manassas    VA
# 20                              P.O. Box 650821    PotomacFalls    VA
# 21                           5019 Backlick Road       annandale    VA
# 22                                171 Childs Rd          Elkton    MD
# 23                             7956 Twist Lane,     Springfield    VA
# 24                                  PO Box 5598       Arlingron    VA
# 25                                P.O. Box 3219        Manassas    VA
# 26                     17005 Silver Arrow Drive        Dumfries    VA
# 27                            4619 West Ox Road         Fairfax    VA
# 28                        2250 Pilot Knob Road,  MendotaHeights    MN
# 29                           6744 Gravel Avenue      Alexandria    VA
# 30                             1502 E Villa St.           Elgin    IL
# 31                         8040 Queenair Drive,    Gaithersburg    MD
# 32                          8040 Queenair Drive  GaithersburgMD  NULL
# 33                                  PO BOX 1895        Brighton    MI
# 34                           415 E. Delray Ave.      Alexandria    VA
# 35                                         NULL            NULL  NULL
# 36                           2200 Second Street      NArlington    Va
# 37                9650 Hawkins Drive, Manassas,            NULL   VA,
#
#    Zip Code       Phone          Fax  \
# 0     22191        NULL         NULL
# 1     22314  7035985514         NULL
# 2     94524  9252703339         NULL
# 3     20109  7036403901         NULL
# 4      NULL  7033390067   7036461009
# 5     22203  7035227354   7035243805
# 6     22150  7035506900  70315502656
# 7     20110  7033680500         NULL
# 8     21223   106084318         NULL
# 9     23431  7039985860   7039986199
# 10    20852  3012024450         NULL
# 11    21244  4102982669   4102984086
# 12     NULL  5405463154         NULL
# 13    22204  7036714602   7036713642
# 14    22306  5716411388         NULL
# 15    20871  3014280800   3014281736
# 16    20166  7034217400   7034332649
# 17    22153  7035692422         NULL
# 18     NULL  3017626990   3017623906
# 19    20109  7033662707         NULL
# 20    20165  5712856158   7039611111
# 21    22003  7038460944         NULL
# 22    21921  9088208800         NULL
# 23    22153  7034518300   7034515062
# 24    22205  7036065013         NULL
# 25    20108  7037750320   8773044016
# 26    22026  2026411065         NULL
# 27    22030  5713287517   5713287640
# 28    55120  6127470759         NULL
# 29    22310  7032243000   7032243001
# 30    60120  8472127030         NULL
# 31    20879  2406312582   2406319015
# 32    20879  3013300983         NULL
# 33    48114  7347484290   7342061796
# 34    22301  7032998880   7032998880
# 35     NULL        NULL         NULL
# 36    22201  7035249292   7035243647
# 37    20109  5714054649         NULL
#
#                                                 Email Paper Collection  \
# 0                        anchan@acedeconstruction.com       :selected:
# 1                              jillh@chapelvalley.com     :unselected:
# 2                  ACCOUNTING @ZEROWASTESOLUTIONS.COM     :unselected:
# 3               environmental@ur.com; jwalker5@ur.com     :unselected:
# 4                            tammy@brandonrushing.com     :unselected:
# 5                                  glenayrapt@aol.com     :unselected:
# 6                              MARELLANO@BARTLETT.COM     :unselected:
# 7                                  khuler@adsimal.com     :unselected:
# 8                           matt@atlanticbiofuelb.net     :unselected:
# 9           SERVICE @CAPITOL SERVICES OF VIRGINIA.COM     :unselected:
# 10                               info@compostcrew.com     :unselected:
# 11                             jmoran@concretecpr.com     :unselected:
# 12                         david.haines@darlingii.com     :unselected:
# 13  maintenance@rentdittmar.com\nmsancho@rentdittm...     :unselected:
# 14                           LHargrove@dmvhauling.com     :unselected:
# 15                                   me@pleasants.org     :unselected:
# 16                        bcontessa@eelandscaping.com     :unselected:
# 17                                brian @function.net     :unselected:
# 18                          kay.grundy@gtownpaper.com       :selected:
# 19                                 eric @idstrash.com     :unselected:
# 20                          ajcostigan@kmghauling.com       :selected:
# 21                 azaleski @lancaster landscapes.com     :unselected:
# 22                           jkura@lorcopetroleum.com     :unselected:
# 23                         info@metalprorecycling.com     :unselected:
# 24                            cactuscove@frontier.com     :unselected:
# 25            jean.poague@patriotdisposalservices.com     :unselected:
# 26                             bbishop@redboxplus.com     :unselected:
# 27                 Ahailegiorgis@republicservices.com     :unselected:
# 28                              licensing@rti-inc.com     :unselected:
# 29                        gretchen@safeguardshred.com     :unselected:
# 30             Chakraborty.simantini@cleanharbors.com     :unselected:
# 31                                mbadeau@seldemo.com     :unselected:
# 32                              cmejia@selhauling.com     :unselected:
# 33                           pdavis@sixnationsinc.com     :unselected:
# 34                       thompsonHauling9@outlook.com     :unselected:
# 35                                               NULL             NULL
# 36                              afentress@ala-inc.com       :selected:
# 37                                   +Jacobsblewm.com     :unselected:
#
#    Electronics Recycling Secure Document Destruction Tire Recycling  \
# 0           :unselected:                :unselected:   :unselected:
# 1           :unselected:                :unselected:   :unselected:
# 2           :unselected:                :unselected:   :unselected:
# 3           :unselected:                :unselected:   :unselected:
# 4           :unselected:                :unselected:   :unselected:
# 5           :unselected:                :unselected:   :unselected:
# 6           :unselected:                :unselected:   :unselected:
# 7           :unselected:                :unselected:   :unselected:
# 8           :unselected:                :unselected:   :unselected:
# 9           :unselected:                :unselected:   :unselected:
# 10          :unselected:                :unselected:   :unselected:
# 11          :unselected:                :unselected:   :unselected:
# 12          :unselected:                :unselected:   :unselected:
# 13          :unselected:                :unselected:   :unselected:
# 14          :unselected:                :unselected:   :unselected:
# 15          :unselected:                :unselected:   :unselected:
# 16          :unselected:                :unselected:   :unselected:
# 17          :unselected:                :unselected:   :unselected:
# 18          :unselected:                :unselected:   :unselected:
# 19          :unselected:                :unselected:   :unselected:
# 20          :unselected:                :unselected:   :unselected:
# 21          :unselected:                :unselected:   :unselected:
# 22          :unselected:                :unselected:   :unselected:
# 23          :unselected:                :unselected:     :selected:
# 24          :unselected:                :unselected:   :unselected:
# 25          :unselected:                :unselected:   :unselected:
# 26          :unselected:                :unselected:   :unselected:
# 27          :unselected:                :unselected:   :unselected:
# 28          :unselected:                :unselected:   :unselected:
# 29          :unselected:                  :selected:   :unselected:
# 30          :unselected:                :unselected:   :unselected:
# 31          :unselected:                :unselected:   :unselected:
# 32          :unselected:                :unselected:   :unselected:
# 33          :unselected:                :unselected:   :unselected:
# 34          :unselected:                :unselected:   :unselected:
# 35                  NULL                        NULL           NULL
# 36            :selected:                :unselected:   :unselected:
# 37          :unselected:                :unselected:   :unselected:
#
#    Solvents/Oil/Antifreeze Recycling Metals Recycling (Ferrous & Non-Ferrous)  \
# 0                       :unselected:                               :selected:
# 1                       :unselected:                             :unselected:
# 2                       :unselected:                             :unselected:
# 3                       :unselected:                             :unselected:
# 4                       :unselected:                             :unselected:
# 5                       :unselected:                             :unselected:
# 6                       :unselected:                             :unselected:
# 7                       :unselected:                             :unselected:
# 8                       :unselected:                             :unselected:
# 9                       :unselected:                             :unselected:
# 10                      :unselected:                             :unselected:
# 11                      :unselected:                             :unselected:
# 12                      :unselected:                             :unselected:
# 13                      :unselected:                             :unselected:
# 14                      :unselected:                             :unselected:
# 15                      :unselected:                             :unselected:
# 16                      :unselected:                             :unselected:
# 17                      :unselected:                             :unselected:
# 18                      :unselected:                             :unselected:
# 19                      :unselected:                             :unselected:
# 20                      :unselected:                             :unselected:
# 21                      :unselected:                             :unselected:
# 22                        :selected:                             :unselected:
# 23                      :unselected:                               :selected:
# 24                      :unselected:                             :unselected:
# 25                      :unselected:                             :unselected:
# 26                      :unselected:                             :unselected:
# 27                      :unselected:                             :unselected:
# 28                      :unselected:                             :unselected:
# 29                      :unselected:                             :unselected:
# 30                      :unselected:                             :unselected:
# 31                      :unselected:                             :unselected:
# 32                      :unselected:                             :unselected:
# 33                      :unselected:                             :unselected:
# 34                      :unselected:                             :unselected:
# 35                              NULL                                     NULL
# 36                        :selected:                               :selected:
# 37                      :unselected:                             :unselected:
#
#    Battery Recycling Yard Maintenance/Landscaping  \
# 0         :selected:                 :unselected:
# 1       :unselected:                 :unselected:
# 2       :unselected:                 :unselected:
# 3       :unselected:                 :unselected:
# 4       :unselected:                   :selected:
# 5       :unselected:                 :unselected:
# 6       :unselected:                   :selected:
# 7       :unselected:                 :unselected:
# 8       :unselected:                 :unselected:
# 9       :unselected:                 :unselected:
# 10      :unselected:                 :unselected:
# 11      :unselected:                 :unselected:
# 12      :unselected:                 :unselected:
# 13      :unselected:                 :unselected:
# 14      :unselected:                 :unselected:
# 15      :unselected:                 :unselected:
# 16      :unselected:                   :selected:
# 17      :unselected:                 :unselected:
# 18      :unselected:                 :unselected:
# 19      :unselected:                 :unselected:
# 20      :unselected:                 :unselected:
# 21      :unselected:                   :selected:
# 22      :unselected:                 :unselected:
# 23      :unselected:                 :unselected:
# 24      :unselected:                 :unselected:
# 25      :unselected:                 :unselected:
# 26      :unselected:                 :unselected:
# 27      :unselected:                 :unselected:
# 28      :unselected:                 :unselected:
# 29      :unselected:                 :unselected:
# 30      :unselected:                 :unselected:
# 31      :unselected:                 :unselected:
# 32      :unselected:                 :unselected:
# 33      :unselected:                 :unselected:
# 34      :unselected:                 :unselected:
# 35              NULL                         NULL
# 36        :selected:                   :selected:
# 37      :unselected:                 :unselected:
#
#    Textile, Shoes, and/or Clothing Recycling  \
# 0                               :unselected:
# 1                               :unselected:
# 2                               :unselected:
# 3                               :unselected:
# 4                               :unselected:
# 5                               :unselected:
# 6                               :unselected:
# 7                               :unselected:
# 8                               :unselected:
# 9                               :unselected:
# 10                              :unselected:
# 11                              :unselected:
# 12                              :unselected:
# 13                              :unselected:
# 14                              :unselected:
# 15                              :unselected:
# 16                              :unselected:
# 17                              :unselected:
# 18                              :unselected:
# 19                              :unselected:
# 20                              :unselected:
# 21                              :unselected:
# 22                              :unselected:
# 23                              :unselected:
# 24                              :unselected:
# 25                              :unselected:
# 26                              :unselected:
# 27                              :unselected:
# 28                              :unselected:
# 29                              :unselected:
# 30                              :unselected:
# 31                              :unselected:
# 32                              :unselected:
# 33                              :unselected:
# 34                              :unselected:
# 35                                      NULL
# 36                                :selected:
# 37                              :unselected:
#
#    Commercial Back-Hauling for Cardboard and Other  \
# 0                                       :selected:
# 1                                     :unselected:
# 2                                     :unselected:
# 3                                     :unselected:
# 4                                     :unselected:
# 5                                     :unselected:
# 6                                     :unselected:
# 7                                     :unselected:
# 8                                     :unselected:
# 9                                     :unselected:
# 10                                    :unselected:
# 11                                    :unselected:
# 12                                    :unselected:
# 13                                    :unselected:
# 14                                    :unselected:
# 15                                    :unselected:
# 16                                    :unselected:
# 17                                    :unselected:
# 18                                    :unselected:
# 19                                    :unselected:
# 20                                      :selected:
# 21                                    :unselected:
# 22                                    :unselected:
# 23                                    :unselected:
# 24                                    :unselected:
# 25                                    :unselected:
# 26                                    :unselected:
# 27                                    :unselected:
# 28                                    :unselected:
# 29                                    :unselected:
# 30                                    :unselected:
# 31                                    :unselected:
# 32                                    :unselected:
# 33                                    :unselected:
# 34                                    :unselected:
# 35                                            NULL
# 36                                      :selected:
# 37                                    :unselected:
#
#    Materials Collection (grocery and other retail outlets)  \
# 0                                        :unselected:
# 1                                        :unselected:
# 2                                        :unselected:
# 3                                        :unselected:
# 4                                        :unselected:
# 5                                        :unselected:
# 6                                        :unselected:
# 7                                        :unselected:
# 8                                        :unselected:
# 9                                        :unselected:
# 10                                       :unselected:
# 11                                       :unselected:
# 12                                         :selected:
# 13                                       :unselected:
# 14                                       :unselected:
# 15                                       :unselected:
# 16                                       :unselected:
# 17                                       :unselected:
# 18                                       :unselected:
# 19                                       :unselected:
# 20                                       :unselected:
# 21                                       :unselected:
# 22                                       :unselected:
# 23                                       :unselected:
# 24                                       :unselected:
# 25                                       :unselected:
# 26                                       :unselected:
# 27                                       :unselected:
# 28                                       :unselected:
# 29                                       :unselected:
# 30                                       :unselected:
# 31                                       :unselected:
# 32                                       :unselected:
# 33                                       :unselected:
# 34                                       :unselected:
# 35                                               NULL
# 36                                         :selected:
# 37                                       :unselected:
#
#    Solid Waste Collection (trash and recycling)  \
# 0                                    :selected:
# 1                                    :selected:
# 2                                    :selected:
# 3                                  :unselected:
# 4                                  :unselected:
# 5                                  :unselected:
# 6                                  :unselected:
# 7                                    :selected:
# 8                                  :unselected:
# 9                                    :selected:
# 10                                 :unselected:
# 11                                   :selected:
# 12                                 :unselected:
# 13                                 :unselected:
# 14                                   :selected:
# 15                                 :unselected:
# 16                                 :unselected:
# 17                                 :unselected:
# 18                                   :selected:
# 19                                 :unselected:
# 20                                   :selected:
# 21                                 :unselected:
# 22                                 :unselected:
# 23                                 :unselected:
# 24                                   :selected:
# 25                                         NULL
# 26                                 :unselected:
# 27                                   :selected:
# 28                                 :unselected:
# 29                                 :unselected:
# 30                                 :unselected:
# 31                                 :unselected:
# 32                                 :unselected:
# 33                                   :selected:
# 34                                   :selected:
# 35                                         NULL
# 36                                   :selected:
# 37                                   :selected:
#
#    Construction and Demolition Debris Collection Bulk Waste & Junk Collection  \
# 0                                     :selected:                 :unselected:
# 1                                   :unselected:                 :unselected:
# 2                                     :selected:                 :unselected:
# 3                                   :unselected:                 :unselected:
# 4                                   :unselected:                 :unselected:
# 5                                   :unselected:                   :selected:
# 6                                   :unselected:                 :unselected:
# 7                                     :selected:                   :selected:
# 8                                   :unselected:                 :unselected:
# 9                                   :unselected:                 :unselected:
# 10                                  :unselected:                 :unselected:
# 11                                  :unselected:                 :unselected:
# 12                                  :unselected:                 :unselected:
# 13                                  :unselected:                 :unselected:
# 14                                  :unselected:                   :selected:
# 15                                    :selected:                 :unselected:
# 16                                  :unselected:                 :unselected:
# 17                                    :selected:                 :unselected:
# 18                                  :unselected:                 :unselected:
# 19                                    :selected:                 :unselected:
# 20                                  :unselected:                 :unselected:
# 21                                  :unselected:                 :unselected:
# 22                                  :unselected:                 :unselected:
# 23                                  :unselected:                 :unselected:
# 24                                  :unselected:                 :unselected:
# 25                                  :unselected:                 :unselected:
# 26                                    :selected:                 :unselected:
# 27                                    :selected:                 :unselected:
# 28                                  :unselected:                 :unselected:
# 29                                  :unselected:                 :unselected:
# 30                                  :unselected:                 :unselected:
# 31                                    :selected:                 :unselected:
# 32                                    :selected:                 :unselected:
# 33                                    :selected:                 :unselected:
# 34                                  :unselected:                   :selected:
# 35                                          NULL                         NULL
# 36                                    :selected:                   :selected:
# 37                                    :selected:                 :unselected:
#
#    Material Recovery Facility (MRF)         Other  \
# 0                      :unselected:  :unselected:
# 1                      :unselected:  :unselected:
# 2                      :unselected:  :unselected:
# 3                      :unselected:    :selected:
# 4                      :unselected:  :unselected:
# 5                      :unselected:  :unselected:
# 6                      :unselected:  :unselected:
# 7                        :selected:  :unselected:
# 8                      :unselected:    :selected:
# 9                      :unselected:  :unselected:
# 10                     :unselected:  :unselected:
# 11                     :unselected:  :unselected:
# 12                     :unselected:  :unselected:
# 13                     :unselected:    :selected:
# 14                     :unselected:  :unselected:
# 15                     :unselected:  :unselected:
# 16                     :unselected:  :unselected:
# 17                     :unselected:  :unselected:
# 18                     :unselected:  :unselected:
# 19                     :unselected:  :unselected:
# 20                     :unselected:  :unselected:
# 21                     :unselected:  :unselected:
# 22                     :unselected:  :unselected:
# 23                     :unselected:  :unselected:
# 24                     :unselected:  :unselected:
# 25                     :unselected:  :unselected:
# 26                     :unselected:  :unselected:
# 27                     :unselected:  :unselected:
# 28                     :unselected:    :selected:
# 29                     :unselected:  :unselected:
# 30                     :unselected:  :unselected:
# 31                     :unselected:  :unselected:
# 32                     :unselected:  :unselected:
# 33                     :unselected:  :unselected:
# 34                     :unselected:  :unselected:
# 35                             NULL          NULL
# 36                       :selected:    :selected:
# 37                     :unselected:  :unselected:
#
#                                        Other-Text         Printed Signature  \
# 0                                            NULL              Anchan Ladia
# 1                                            NULL             Jill Hartkopf
# 2                                            NULL            JESSICA SEXTON
# 3                   Septage/Portable Toilet Waste            Jeffrey Walker
# 4                                            NULL                      NULL
# 5                                            NULL          Deborah J. House
# 6                                            NULL                      NULL
# 7                                            NULL         Heather Mccracken
# 8             USED Cooking OIL Pickup & REcadilly                MATT TOPAS
# 9                                            NULL             DAVID J. DUNN
# 10                     Compost/Organics Recycling         Joanne Lesperance
# 11                                           NULL                John Moran
# 12                                           NULL              David Haines
# 13  see additional comments and/or clarifications             Kevin England
# 14                                           NULL             Leon Hargrove
# 15                                           NULL          E. Michael Ensor
# 16                                           NULL          Brianna Contessa
# 17                                           NULL              Brian Martel
# 18                                           NULL                Kay Grundy
# 19                                           NULL           Eric Rotenberry
# 20                                           NULL             A.J. Costigan
# 21                                           NULL          adrienne Zaleski
# 22                                           NULL                James Kura
# 23                                           NULL           Kelle J. Motsko
# 24                                           NULL             Shirley Gomez
# 25                                           NULL               JeanPolaque
# 26                                           NULL              Brian Bishop
# 27                                           NULL        Addis Hailegiorgis
# 28                               Used Cooking Oil             Jenn Sundberg
# 29                                           NULL        Gretchen Schofield
# 30                                           NULL     Simantini Chakraborty
# 31                                           NULL            Thomas Wootton
# 32                                           NULL                      NULL
# 33                                           NULL                Paul Davis
# 34                                           NULL                   Partner
# 35                                           NULL                      NULL
# 36                        Multi-Housing Community         April L. Fentress
# 37                                           NULL  Than Jarls Jord\n2/14/24
#
#          Signed Date                                        Methodology  \
# 0          1/09/2024                                               NULL
# 1         01/05/2024                                               NULL
# 2          1/31/2024                                               NULL
# 3           1/3/2024  We estimate we will collect 200,000 gallons of...
# 4               NULL  1 bag of debris per client for 40 weeks per ye...
# 5           1/3/2024                                               NULL
# 6           12/28/25  Remington Mulch does not provide tonnage or me...
# 7          1/12/2024                                               NULL
# 8            1 31/24                                                  =
# 9          1-29-2024  IN ARLINGTON COUNTY AND THE CITY OF ALEXANDRIA...
# 10          01/22/24  We calculated total residential customers in A...
# 11         1/11/2020                                               NULL
# 12           3/20/24                                               NULL
# 13  January 11, 2024  Property names are recorded on dump ticket at ...
# 14        02/13/2024                                               NULL
# 15         1-24-2024                                               NULL
# 16    Date:1/30/2024                                               NULL
# 17            3/7/24                                               NULL
# 18   Date:01/30/2023                                               NULL
# 19            2/1/24  Company Hauling To was down 1.56% year over ye...
# 20        01/23/2024                                               NULL
# 21              NULL                                               NULL
# 22         1/31/2024                                               NULL
# 23        01/18/2024                                               NULL
# 24         1/18/2024                                               NULL
# 25            2/1/24                                               NULL
# 26         1/24/2024   I keep track on a spreadsheet based on zip code.
# 27        01/17/2024  Commerical estimates are based on % of a route...
# 28          1/3/2023                                               NULL
# 29           3/20124                                               NULL
# 30        02/07/2024                                               NULL
# 31         1-08-2024                                               NULL
# 32           1/12/24                                               NULL
# 33           1-26-24  Actual tickets ans our trucks have scales with...
# 34        02/22/2024                                               NULL
# 35              NULL                                               NULL
# 36         1-31-2024                                               NULL
# 37           2/14/24                                               NULL
#
#                                              Comments Handwritten?
# 0                                                NULL         True
# 1                                                NULL         True
# 2                                                NULL         True
# 3                                                NULL         True
# 4                                                NULL         NULL
# 5                             Appliance and Furniture         True
# 6                                                same         True
# 7                                                NULL         True
# 8                                                NULL         True
# 9                                                NULL         True
# 10                                               NULL         NULL
# 11                                               NULL         True
# 12               INCLUDES :\nREST GREASE\nTRAP GREASE         True
# 13  OUR TRASH TRUCK ASSISTS DITTMAR RENTAL PROPERT...         True
# 14                                               NULL         True
# 15                                               NULL         True
# 16                                               NULL         True
# 17                                               NULL         True
# 18                                               NULL         True
# 19                                               NULL         True
# 20                                               NULL         True
# 21                                               NULL         True
# 22                                               NULL         True
# 23                                               NULL         True
# 24                                               NULL         True
# 25                                               NULL         True
# 26                                               NULL         True
# 27                                               NULL         NULL
# 28  RTI Delivers Fresh cooking Oil, retreives used...         True
# 29                                               NULL         True
# 30                                               NULL         True
# 31                                               NULL         True
# 32                                               NULL         True
# 33                                               NULL         True
# 34                                               NULL         True
# 35                                               NULL         True
# 36                                               NULL         True
# 37                                               NULL         True

# %% [markdown]
# ### Section B

# %%
def code_strings(df, column_name):
  mapping = {'Yes': 'Y', 'yes': 'Y', 'YES': 'Y', 'No': 'N', 'no': 'N', 'NO': 'N'}
  df[column_name] = df[column_name].replace(mapping)
  return df

# %%
SectionBTotal = pd.DataFrame()
SkippedFiles = []
for filename in os.listdir(output_folder_path):
    if filename.endswith(".json"):
        file_path = os.path.join(output_folder_path, filename)
        try:
            with open(file_path, "r") as json_file:
                print(f"-------->Reading {filename}<---------")

                json_data = json.load(json_file)
                documents_list = json_data.get("documents", [])
                for document in documents_list:
                    SectionBT = pd.DataFrame()
                    
                    fields_dict = document.get("fields", {})
                    section_b_page1 = fields_dict.get("SectionB-Page1", {})
                    section_b_page2 = fields_dict.get("SectionB-Page2", {})
                    value_list = section_b_page1.get("value", [])
                    value_list2 = section_b_page2.get("value", [])
                    data_list_B = []
                    data_list_B2 = []

                    for item in value_list:
                        field_data_B = {}
                        column1_value = item.get("value", {}).get("COLUMN1", {}).get("value", "")
                        field_data_B["Material"] = column1_value

                        tons_recycled_value = item.get("value", {}).get("Tons Recycled", {}).get("value", "")
                        field_data_B["Tons Recycled"] = tons_recycled_value

                        estimate_value = item.get("value", {}).get("Estimate? (Y/N)", {}).get("value", "")
                        field_data_B["Estimate? (Y/N)"] = estimate_value

                        source_code_value = item.get("value", {}).get("Source Code", {}).get("value", "")
                        field_data_B["Source Code"] = source_code_value

                        facility_value = item.get("value", {}).get("Name & Address of Processing Facility(s) by ton", {}).get("value", "")
                        field_data_B["Name & Address of Processing Facility(s) by ton"] = facility_value
                        
                        data_list_B.append(field_data_B)
                    df_B = pd.DataFrame(data_list_B)

                    for item in value_list2:
                        field_data_B2 = {}
                        column1_value = item.get("value", {}).get("COLUMN1", {}).get("value", "")
                        field_data_B2["Material"] = column1_value

                        tons_recycled_value = item.get("value", {}).get("Tons Recycled", {}).get("value", "")
                        field_data_B2["Tons Recycled"] = tons_recycled_value

                        estimate_value = item.get("value", {}).get("Estimate? (Y/N)", {}).get("value", "")
                        field_data_B2["Estimate? (Y/N)"] = estimate_value

                        source_code_value = item.get("value", {}).get("Source Code", {}).get("value", "")
                        field_data_B2["Source Code"] = source_code_value

                        facility_value = item.get("value", {}).get("Name & Address of Processing Facility(s) by ton", {}).get("value", "")
                        field_data_B2["Name & Address of Processing Facility(s) by ton"] = facility_value

                        data_list_B2.append(field_data_B2)
                    df_B_2 = pd.DataFrame(data_list_B2)
                    
                    SectionB = pd.concat([df_B, df_B_2], axis=0)

                    SectionB.reset_index(drop=True, inplace=True)
                    # Removing Unwanted characters
                    SectionB.iloc[:, 1] = SectionB.iloc[:, 1].replace(',', '', regex=True)
                    SectionB = SectionB.map(lambda x: str(x).replace(':selected:', ''))
                    SectionB = SectionB.map(lambda x: str(x).replace('\n', ''))
                    SectionB = SectionB.map(lambda x: str(x).replace('nan', ''))

                    strings_to_check = ['TONS RECYCLED', 'ESTIMATE? (Y/N)', 'SOURCE CODE', 'NAME & ADDRESS OF PROCESSING FACILITY(S) BY TON']
                    SectionB = SectionB[~(SectionB.iloc[:, 1].str.upper().isin(strings_to_check))]# | SectionB.iloc[:, 2].str.upper().isin(strings_to_check))]
                    SectionB.iloc[:, 0] = SectionB.iloc[:, 0].replace("", None).ffill()

                    # Adding columns
                    SectionB['Filename'] = filename
                    SectionB['Section'] = 'Section B'
                    
                    SectionBTotal = pd.concat([SectionBTotal, SectionB], ignore_index=True)
        except Exception as e:
            SkippedFiles.append(filename)
            print(f"Skipping file {filename} due to error: {str(e)}")
            continue


# applying string transofrmation fr Source Code
SectionBTotal = code_strings(SectionBTotal, 'Estimate? (Y/N)')

# Removing Materials with Null values
SectionBTotal['Tons Recycled'] = SectionBTotal['Tons Recycled'].str.replace(r'[^\d. -]', '', regex=True)
SectionBTotal = SectionBTotal[SectionBTotal['Tons Recycled'].isin([0, "0", "o", pd.NA, 'N/A']) == False]
SectionBTotal = SectionBTotal.replace("", "NULL")
#SectionBTotal = SectionBTotal.dropna(subset=['Tons Recycled'])

SectionBTotal.head(10)
# Out:
# -------->Reading 2023 Annual Tonnage Report ACE.json<---------
# -------->Reading 2023 Annual Tonnage Report Chapel Valley.json<---------
# -------->Reading 2023 Annual Tonnage Report Zero Waste Solutions.json<---------
# -------->Reading 2023 Arlington Annual Tonnage Report-United Rentals.json<---------
# -------->Reading 2023 Arlington Annual Tonnage Report.json<---------
# -------->Reading 2023 Glenayr Apartments Tonnage Report.json<---------
# -------->Reading 2023 Tonnage Report - Bartlett Tree.json<---------
# -------->Reading ADS 2023 Tonnage Report.json<---------
# -------->Reading Atlantic Biofuels Tonnage Report.json<---------
# -------->Reading Capitol Services Tonnage Report 2024 Arlington County.json<---------
# -------->Reading Compost Crew Annual Tonnage Report Arlingon.json<---------
# -------->Reading Concrete Protection and Restoration 2023 Tonnage Report.json<---------
# -------->Reading Darling Ingredients Tonnage Report.json<---------
# -------->Reading Dittmar 2023 Annual Tonnage Report.json<---------
# -------->Reading DMV Hauling Tonnage Report.json<---------
# -------->Reading EAI Arlington Tonnage Report 2024.json<---------
# -------->Reading Environmental Enhancements 2023 Annual Tonnage Report.json<---------
# -------->Reading function enterprises.json<---------
# -------->Reading georgetown paper stock tonnage report.json<---------
# -------->Reading Industrial Disposal Arlington Recycling report 2023.json<---------
# -------->Reading kmG Tonnage Report.json<---------
# -------->Reading Lancaster Landscapes Tonnage Report.json<---------
# Skipping file Lancaster Landscapes Tonnage Report.json due to error: single positional indexer is out-of-bounds
# -------->Reading Lorco Annual Tonnage Report (Signed).json<---------
# -------->Reading Metal Pro Tonnage Report.json<---------
# -------->Reading Olivo 2023 Annual Tonnage Report.json<---------
# -------->Reading Patriot Disposal Arlington County Tonnage Report 2023.json<---------
# -------->Reading Redbox 2023 Annual Tonnage Report (005).json<---------
# -------->Reading Republic Arlington County Recycling & Refuse Tonnage Report CY 2023.json<---------
# -------->Reading RTI 2023 Annual Tonnage Report.json<---------
# -------->Reading Safeguard Shredding Tonnage Report.json<---------
# -------->Reading Safety kleen Systems Tonnage Report.json<---------
# -------->Reading Selective Demolition Tonnage Report.json<---------
# -------->Reading Selective Hauling Tonnage Report.json<---------
# -------->Reading Six Nations 2023 Annual Tonnage Report.json<---------
# -------->Reading Thompson Hauling Tonnage Report.json<---------
# -------->Reading Trash Away Tonnage Report.json<---------
# -------->Reading Washington and Lee Apartments Tonnage Report.json<---------
# -------->Reading Waste Management Arlington 2023 Tonnage Report.json<---------
#                                Material Tons Recycled Estimate? (Y/N)  \
# 0    Single Stream/All in One Recycling          NULL            NULL
# 1  Bottles & Cans Only (no paper items)          NULL            NULL
# 2                           Mixed Paper          NULL            NULL
# 3                             Cardboard           104               N
# 4                            Newspapers          NULL            NULL
# 5                        Shredded Paper          NULL            NULL
# 6                            Appliances          NULL            NULL
# 7            Inoperative Motor Vehicles          NULL            NULL
# 8                         Aluminum Cans          NULL            NULL
# 9                     Other Scrap Metal            59               N
#
#   Source Code Name & Address of Processing Facility(s) by ton  \
# 0        NULL                                            NULL
# 1        NULL                                            NULL
# 2        NULL                                            NULL
# 3        NULL                                       Broad Run
# 4        NULL                                            NULL
# 5        NULL                                            NULL
# 6        NULL                                            NULL
# 7        NULL                                            NULL
# 8        NULL                                            NULL
# 9        NULL                                Woodbridge Metal
#
#                               Filename    Section
# 0  2023 Annual Tonnage Report ACE.json  Section B
# 1  2023 Annual Tonnage Report ACE.json  Section B
# 2  2023 Annual Tonnage Report ACE.json  Section B
# 3  2023 Annual Tonnage Report ACE.json  Section B
# 4  2023 Annual Tonnage Report ACE.json  Section B
# 5  2023 Annual Tonnage Report ACE.json  Section B
# 6  2023 Annual Tonnage Report ACE.json  Section B
# 7  2023 Annual Tonnage Report ACE.json  Section B
# 8  2023 Annual Tonnage Report ACE.json  Section B
# 9  2023 Annual Tonnage Report ACE.json  Section B

# %%
word_list_data = []

for filename in os.listdir(output_folder_path):
    if filename.endswith(".json"):
        file = os.path.join(output_folder_path, filename)
        with open(file, 'r') as json_file:
            json_data = json.load(json_file)
            page_list = json_data.get("pages", [])
            for page in page_list:
                word_list = page.get("words", [])
                for word in word_list:
                    word_content = word["content"]
                    word_confidence = word["confidence"]
                    word_list_data.append({"word": word_content, "confidence": word_confidence, "filename": filename})

word_df = pd.DataFrame(word_list_data)
word_df.head(10)
# Out:
#         word  confidence                             filename
# 0  ARLINGTON       0.993  2023 Annual Tonnage Report ACE.json
# 1   VIRGINIA       0.992  2023 Annual Tonnage Report ACE.json
# 2       Page       0.993  2023 Annual Tonnage Report ACE.json
# 3          1       0.997  2023 Annual Tonnage Report ACE.json
# 4         of       0.995  2023 Annual Tonnage Report ACE.json
# 5          9       0.995  2023 Annual Tonnage Report ACE.json
# 6  Arlington       0.993  2023 Annual Tonnage Report ACE.json
# 7     County       0.994  2023 Annual Tonnage Report ACE.json
# 8  Recycling       0.993  2023 Annual Tonnage Report ACE.json
# 9          &       0.964  2023 Annual Tonnage Report ACE.json

# %%
def calculate_average_confidence(material, filename):
    confidences = []
    current_word = ""
    for word in material.split():
        current_word += word
        confidence = word_df[(word_df['word'] == current_word) & (word_df['filename'] == filename)]['confidence'].values
        if len(confidence) > 0:
            confidences.append(confidence[0])
            current_word = ""
    return sum(confidences) / len(confidences) if confidences else 0

text_columns = [col for col in SectionBTotal.columns if col not in ['Filename', 'Section']]
SectionBTotal_Confidence = SectionBTotal.copy()
for col in text_columns:
    SectionBTotal_Confidence[col + '_confidence'] = SectionBTotal_Confidence.apply(lambda row: calculate_average_confidence(str(row[col]), row['Filename']), axis=1)

# Replacing zeros with hundred
SectionBTotal_Confidence.replace(0, "NULL", inplace=True)

SectionBTotal_Confidence.head()
# Out:
#                                Material Tons Recycled Estimate? (Y/N)  \
# 0    Single Stream/All in One Recycling          NULL            NULL
# 1  Bottles & Cans Only (no paper items)          NULL            NULL
# 2                           Mixed Paper          NULL            NULL
# 3                             Cardboard           104               N
# 4                            Newspapers          NULL            NULL
#
#   Source Code Name & Address of Processing Facility(s) by ton  \
# 0        NULL                                            NULL
# 1        NULL                                            NULL
# 2        NULL                                            NULL
# 3        NULL                                       Broad Run
# 4        NULL                                            NULL
#
#                               Filename    Section  Material_confidence  \
# 0  2023 Annual Tonnage Report ACE.json  Section B             0.994600
# 1  2023 Annual Tonnage Report ACE.json  Section B             0.988571
# 2  2023 Annual Tonnage Report ACE.json  Section B             0.995000
# 3  2023 Annual Tonnage Report ACE.json  Section B             0.995000
# 4  2023 Annual Tonnage Report ACE.json  Section B             0.994000
#
#   Tons Recycled_confidence Estimate? (Y/N)_confidence Source Code_confidence  \
# 0                     NULL                       NULL                   NULL
# 1                     NULL                       NULL                   NULL
# 2                     NULL                       NULL                   NULL
# 3                    0.997                       0.98                   NULL
# 4                     NULL                       NULL                   NULL
#
#   Name & Address of Processing Facility(s) by ton_confidence
# 0                                               NULL
# 1                                               NULL
# 2                                               NULL
# 3                                             0.9945
# 4                                               NULL

# %%
SectionCTotal = pd.DataFrame()

for filename in os.listdir(output_folder_path):
    if filename.endswith(".json"):
        file_path = os.path.join(output_folder_path, filename)
        try:
            with open(file_path, "r") as json_file:
                print(f"-------->Reading {filename}<---------")

                json_data = json.load(json_file)
                documents_list = json_data.get("documents", [])
                for document in documents_list:
                    SectionCT = pd.DataFrame()
                    
                    fields_dict = document.get("fields", {})
                    section_c = fields_dict.get("SectionC", {})
                    value_list = section_c.get("value", [])
                    
                    data_list_C = []

                    for item in value_list:
                        field_data_C = {}
                        column1_value = item.get("value", {}).get("COLUMN1", {}).get("value", "")
                        field_data_C["Material"] = column1_value

                        # Assuming these keys are present in your JSON structure
                        tons_recycled_value = item.get("value", {}).get("Tons Recycled", {}).get("value", "")
                        field_data_C["Tons Recycled"] = tons_recycled_value

                        estimate_value = item.get("value", {}).get("Estimate? (Y/N)", {}).get("value", "")
                        field_data_C["Estimate? (Y/N)"] = estimate_value

                        source_code_value = item.get("value", {}).get("Source Code", {}).get("value", "")
                        field_data_C["Source Code"] = source_code_value

                        facility_value = item.get("value", {}).get("Name & Address of Processing Facility(s) by ton", {}).get("value", "")
                        field_data_C["Name & Address of Processing Facility(s) by ton"] = facility_value

                        data_list_C.append(field_data_C)
                    SectionC = pd.DataFrame(data_list_C)
                    
                    SectionC.reset_index(drop=True, inplace=True)
                    SectionC.iloc[:, 1] = SectionC.iloc[:, 1].replace(',', '', regex=True)
                    SectionC = SectionC.map(lambda x: str(x).replace(':selected:', ''))
                    SectionC = SectionC.map(lambda x: str(x).replace('\n', ''))
                    SectionC = SectionC.map(lambda x: str(x).replace('nan', ''))

                    strings_to_check = ['TONS RECYCLED', 'ESTIMATE? (Y/N)', 'SOURCE CODE', 'NAME & ADDRESS OF PROCESSING FACILITY(S) BY TON']
                    SectionC = SectionC[~(SectionC.iloc[:, 1].str.upper().isin(strings_to_check))]# | SectionB.iloc[:, 2].str.upper().isin(strings_to_check))]
                    SectionC.iloc[:, 0] = SectionC.iloc[:, 0].replace("", None).ffill()

                    # Adding columns
                    SectionC['Filename'] = filename
                    SectionC['Section'] = 'Section C'

                    SectionCTotal = pd.concat([SectionCTotal, SectionC], ignore_index=True)

        except Exception as e:
            SkippedFiles.append(filename)
            print(f"Skipping file {filename} due to error: {str(e)}")
            continue

SectionCTotal = code_strings(SectionCTotal, 'Estimate? (Y/N)')
                        
# Removing Materials with Null values
SectionCTotal['Tons Recycled'] = SectionCTotal['Tons Recycled'].str.replace(r'[^\d. -]', '', regex=True)
SectionCTotal = SectionCTotal[SectionCTotal['Tons Recycled'].isin([0, "0", "o", pd.NA, 'N/A']) == False]
SectionCTotal = SectionCTotal.replace("", "NULL")
#SectionCTotal = SectionCTotal.dropna(subset=['Tons Recycled'])

SectionCTotal.head(10)
# Out:
# -------->Reading 2023 Annual Tonnage Report ACE.json<---------
# -------->Reading 2023 Annual Tonnage Report Chapel Valley.json<---------
# -------->Reading 2023 Annual Tonnage Report Zero Waste Solutions.json<---------
# -------->Reading 2023 Arlington Annual Tonnage Report-United Rentals.json<---------
# -------->Reading 2023 Arlington Annual Tonnage Report.json<---------
# -------->Reading 2023 Glenayr Apartments Tonnage Report.json<---------
# -------->Reading 2023 Tonnage Report - Bartlett Tree.json<---------
# -------->Reading ADS 2023 Tonnage Report.json<---------
# -------->Reading Atlantic Biofuels Tonnage Report.json<---------
# -------->Reading Capitol Services Tonnage Report 2024 Arlington County.json<---------
# -------->Reading Compost Crew Annual Tonnage Report Arlingon.json<---------
# -------->Reading Concrete Protection and Restoration 2023 Tonnage Report.json<---------
# -------->Reading Darling Ingredients Tonnage Report.json<---------
# -------->Reading Dittmar 2023 Annual Tonnage Report.json<---------
# -------->Reading DMV Hauling Tonnage Report.json<---------
# -------->Reading EAI Arlington Tonnage Report 2024.json<---------
# -------->Reading Environmental Enhancements 2023 Annual Tonnage Report.json<---------
# -------->Reading function enterprises.json<---------
# -------->Reading georgetown paper stock tonnage report.json<---------
# -------->Reading Industrial Disposal Arlington Recycling report 2023.json<---------
# -------->Reading kmG Tonnage Report.json<---------
# -------->Reading Lancaster Landscapes Tonnage Report.json<---------
# Skipping file Lancaster Landscapes Tonnage Report.json due to error: single positional indexer is out-of-bounds
# -------->Reading Lorco Annual Tonnage Report (Signed).json<---------
# -------->Reading Metal Pro Tonnage Report.json<---------
# -------->Reading Olivo 2023 Annual Tonnage Report.json<---------
# -------->Reading Patriot Disposal Arlington County Tonnage Report 2023.json<---------
# -------->Reading Redbox 2023 Annual Tonnage Report (005).json<---------
# -------->Reading Republic Arlington County Recycling & Refuse Tonnage Report CY 2023.json<---------
# -------->Reading RTI 2023 Annual Tonnage Report.json<---------
# -------->Reading Safeguard Shredding Tonnage Report.json<---------
# -------->Reading Safety kleen Systems Tonnage Report.json<---------
# -------->Reading Selective Demolition Tonnage Report.json<---------
# -------->Reading Selective Hauling Tonnage Report.json<---------
# -------->Reading Six Nations 2023 Annual Tonnage Report.json<---------
# -------->Reading Thompson Hauling Tonnage Report.json<---------
# Skipping file Thompson Hauling Tonnage Report.json due to error: single positional indexer is out-of-bounds
# -------->Reading Trash Away Tonnage Report.json<---------
# -------->Reading Washington and Lee Apartments Tonnage Report.json<---------
# -------->Reading Waste Management Arlington 2023 Tonnage Report.json<---------
#                                     Material Tons Recycled Estimate? (Y/N)  \
# 0                          Fluorescent Lamps           1.5               N
# 1                                      Paint          NULL            NULL
# 2  Textiles (clothing, shoes, leather, etc.)          NULL            NULL
# 3                                  Furniture          NULL            NULL
# 4                                      Books          NULL            NULL
# 5                          Fluorescent Lamps          NULL            NULL
# 6                                      Paint          NULL            NULL
# 7  Textiles (clothing, shoes, leather, etc.)          NULL            NULL
# 8                                  Furniture          NULL            NULL
# 9                                      Books          NULL            NULL
#
#   Source Code Name & Address of Processing Facility(s) by ton  \
# 0        NULL                              Lighting Resources
# 1        NULL                                            NULL
# 2        NULL                                            NULL
# 3        NULL                                            NULL
# 4        NULL                                            NULL
# 5        NULL                                            NULL
# 6        NULL                                            NULL
# 7        NULL                                            NULL
# 8        NULL                                            NULL
# 9        NULL                                            NULL
#
#                                         Filename    Section
# 0            2023 Annual Tonnage Report ACE.json  Section C
# 1            2023 Annual Tonnage Report ACE.json  Section C
# 2            2023 Annual Tonnage Report ACE.json  Section C
# 3            2023 Annual Tonnage Report ACE.json  Section C
# 4            2023 Annual Tonnage Report ACE.json  Section C
# 5  2023 Annual Tonnage Report Chapel Valley.json  Section C
# 6  2023 Annual Tonnage Report Chapel Valley.json  Section C
# 7  2023 Annual Tonnage Report Chapel Valley.json  Section C
# 8  2023 Annual Tonnage Report Chapel Valley.json  Section C
# 9  2023 Annual Tonnage Report Chapel Valley.json  Section C

# %%
text_columns = [col for col in SectionCTotal.columns if col not in ['Filename', 'Section']]
SectionCTotal_Confidence = SectionCTotal.copy()
for col in text_columns:
    SectionCTotal_Confidence[col + '_confidence'] = SectionCTotal_Confidence.apply(lambda row: calculate_average_confidence(str(row[col]), row['Filename']), axis=1)

# Replacing zeros with hundred
SectionCTotal_Confidence.replace(0, "NULL", inplace=True)

SectionCTotal_Confidence.head()
# Out:
#                                     Material Tons Recycled Estimate? (Y/N)  \
# 0                          Fluorescent Lamps           1.5               N
# 1                                      Paint          NULL            NULL
# 2  Textiles (clothing, shoes, leather, etc.)          NULL            NULL
# 3                                  Furniture          NULL            NULL
# 4                                      Books          NULL            NULL
#
#   Source Code Name & Address of Processing Facility(s) by ton  \
# 0        NULL                              Lighting Resources
# 1        NULL                                            NULL
# 2        NULL                                            NULL
# 3        NULL                                            NULL
# 4        NULL                                            NULL
#
#                               Filename    Section Material_confidence  \
# 0  2023 Annual Tonnage Report ACE.json  Section C              0.9905
# 1  2023 Annual Tonnage Report ACE.json  Section C               0.995
# 2  2023 Annual Tonnage Report ACE.json  Section C              0.9934
# 3  2023 Annual Tonnage Report ACE.json  Section C               0.994
# 4  2023 Annual Tonnage Report ACE.json  Section C               0.995
#
#   Tons Recycled_confidence Estimate? (Y/N)_confidence Source Code_confidence  \
# 0                    0.997                       0.98                   NULL
# 1                     NULL                       NULL                   NULL
# 2                     NULL                       NULL                   NULL
# 3                     NULL                       NULL                   NULL
# 4                     NULL                       NULL                   NULL
#
#   Name & Address of Processing Facility(s) by ton_confidence
# 0                                             0.9935
# 1                                               NULL
# 2                                               NULL
# 3                                               NULL
# 4                                               NULL

# %% [markdown]
# ### Section D

# %%
SectionDTotal = pd.DataFrame()

for filename in os.listdir(output_folder_path):
    if filename.endswith(".json"):
        file_path = os.path.join(output_folder_path, filename)
        try:
            with open(file_path, "r") as json_file:
                print(f"-------->Reading {filename}<---------")

                json_data = json.load(json_file)
                documents_list = json_data.get("documents", [])
                for document in documents_list:
                    SectionDT = pd.DataFrame()
                    
                    fields_dict = document.get("fields", {})
                    section_d_page1 = fields_dict.get("SectionD-Page1", {})
                    value_list_d1 = section_d_page1.get("value", [])
                    section_d_page2 = fields_dict.get("SectionD-Page2", {})
                    value_list_d2 = section_d_page2.get("value", [])

                    data_list_D1 = []
                    data_list_D2 = []

                    for item in value_list_d1:
                        field_data_D = {}
                        column1_value = item.get("value", {}).get("COLUMN1", {}).get("value", "")
                        field_data_D["Disposed/Recycled/Reused"] = column1_value

                        material_value = item.get("value", {}).get("Material", {}).get("value", "")
                        field_data_D["Material"] = material_value

                        tons_collected_value = item.get("value", {}).get("Tons Collected", {}).get("value", "")
                        field_data_D["Tons Collected"] = tons_collected_value

                        estimate_value = item.get("value", {}).get("Estimate? (Y/N)", {}).get("value", "")
                        field_data_D["Estimate? (Y/N)"] = estimate_value

                        facility_value = item.get("value", {}).get("Location(s) Where Disposed/Recycled/Reused", {}).get("value", "")
                        field_data_D["Location(s) Where Disposed/Recycled/Reused"] = facility_value

                        data_list_D1.append(field_data_D)
                    df_D1 = pd.DataFrame(data_list_D1)

                    for item in value_list_d2:
                        field_data_D2 = {}
                        column1_value = item.get("value", {}).get("COLUMN1", {}).get("value", "")
                        field_data_D2["Disposed/Recycled/Reused"] = column1_value

                        material_value = item.get("value", {}).get("Material", {}).get("value", "")
                        field_data_D2["Material"] = material_value

                        tons_collected_value = item.get("value", {}).get("Tons Collected", {}).get("value", "")
                        field_data_D2["Tons Collected"] = tons_collected_value

                        estimate_value = item.get("value", {}).get("Estimate? (Y/N)", {}).get("value", "")
                        field_data_D2["Estimate? (Y/N)"] = estimate_value

                        facility_value = item.get("value", {}).get("Location(s) Where Disposed/Recycled/Reused", {}).get("value", "")
                        field_data_D2["Location(s) Where Disposed/Recycled/Reused"] = facility_value

                        data_list_D2.append(field_data_D2)
                    df_D2 = pd.DataFrame(data_list_D2)

                    SectionD = pd.concat([df_D1, df_D2], axis=0)
                    SectionD.reset_index(drop=True, inplace=True)
                    SectionD.iloc[:, 1] = SectionD.iloc[:, 1].replace(',', '', regex=True)
                    SectionD = SectionD.map(lambda x: str(x).replace(':selected:', ''))
                    SectionD = SectionD.map(lambda x: str(x).replace('\n', ''))
                    SectionD = SectionD.map(lambda x: str(x).replace('nan', ''))

                    SectionD.iloc[:, 0] = SectionD.iloc[:, 0].replace("", None).ffill()

                    strings_to_check = ['MATERIAL','TONS COLLECTED', 'ESTIMATE? (Y/N)', 'LOCATION(S) WHERE DISPOSED/RECYCLED/REUSED']
                    SectionD = SectionD[~(SectionD.iloc[:, 1].str.upper().isin(strings_to_check))]# | SectionB.iloc[:, 2].str.upper().isin(strings_to_check))]
                    SectionD.iloc[:, 0] = SectionD.iloc[:, 0].replace("", None).ffill()

                    # Adding columns
                    SectionD['Filename'] = filename
                    SectionD['Section'] = 'Section D'

                    SectionDTotal = pd.concat([SectionDTotal, SectionD], ignore_index=True)

        except Exception as e:
            SkippedFiles.append(filename)
            print(f"Skipping file {filename} due to error: {str(e)}")
            continue

SectionDTotal = code_strings(SectionDTotal, 'Estimate? (Y/N)')
                  
# Removing Materials with Null values
SectionDTotal['Tons Collected'] = SectionDTotal['Tons Collected'].str.replace(r'[^\d. -]', '', regex=True)
SectionDTotal['Disposed/Recycled/Reused'] = SectionDTotal['Disposed/Recycled/Reused'].str.replace('Disposed Recycled', 'Recycled')

SectionDTotal = SectionDTotal[SectionDTotal['Tons Collected'].isin([0, "0", "o", pd.NA, 'N/A']) == False]
SectionDTotal = SectionDTotal.replace("", "NULL")
#SectionDTotal = SectionDTotal.dropna(subset=['Tons Collected'])

SectionDTotal.head(10)
# Out:
# -------->Reading 2023 Annual Tonnage Report ACE.json<---------
# -------->Reading 2023 Annual Tonnage Report Chapel Valley.json<---------
# -------->Reading 2023 Annual Tonnage Report Zero Waste Solutions.json<---------
# -------->Reading 2023 Arlington Annual Tonnage Report-United Rentals.json<---------
# -------->Reading 2023 Arlington Annual Tonnage Report.json<---------
# -------->Reading 2023 Glenayr Apartments Tonnage Report.json<---------
# -------->Reading 2023 Tonnage Report - Bartlett Tree.json<---------
# -------->Reading ADS 2023 Tonnage Report.json<---------
# -------->Reading Atlantic Biofuels Tonnage Report.json<---------
# -------->Reading Capitol Services Tonnage Report 2024 Arlington County.json<---------
# -------->Reading Compost Crew Annual Tonnage Report Arlingon.json<---------
# -------->Reading Concrete Protection and Restoration 2023 Tonnage Report.json<---------
# -------->Reading Darling Ingredients Tonnage Report.json<---------
# -------->Reading Dittmar 2023 Annual Tonnage Report.json<---------
# -------->Reading DMV Hauling Tonnage Report.json<---------
# -------->Reading EAI Arlington Tonnage Report 2024.json<---------
# -------->Reading Environmental Enhancements 2023 Annual Tonnage Report.json<---------
# -------->Reading function enterprises.json<---------
# -------->Reading georgetown paper stock tonnage report.json<---------
# -------->Reading Industrial Disposal Arlington Recycling report 2023.json<---------
# -------->Reading kmG Tonnage Report.json<---------
# -------->Reading Lancaster Landscapes Tonnage Report.json<---------
# Skipping file Lancaster Landscapes Tonnage Report.json due to error: single positional indexer is out-of-bounds
# -------->Reading Lorco Annual Tonnage Report (Signed).json<---------
# -------->Reading Metal Pro Tonnage Report.json<---------
# -------->Reading Olivo 2023 Annual Tonnage Report.json<---------
# -------->Reading Patriot Disposal Arlington County Tonnage Report 2023.json<---------
# -------->Reading Redbox 2023 Annual Tonnage Report (005).json<---------
# -------->Reading Republic Arlington County Recycling & Refuse Tonnage Report CY 2023.json<---------
# -------->Reading RTI 2023 Annual Tonnage Report.json<---------
# -------->Reading Safeguard Shredding Tonnage Report.json<---------
# -------->Reading Safety kleen Systems Tonnage Report.json<---------
# -------->Reading Selective Demolition Tonnage Report.json<---------
# -------->Reading Selective Hauling Tonnage Report.json<---------
# -------->Reading Six Nations 2023 Annual Tonnage Report.json<---------
# -------->Reading Thompson Hauling Tonnage Report.json<---------
# -------->Reading Trash Away Tonnage Report.json<---------
# -------->Reading Washington and Lee Apartments Tonnage Report.json<---------
# -------->Reading Waste Management Arlington 2023 Tonnage Report.json<---------
#   Disposed/Recycled/Reused      Material Tons Collected Estimate? (Y/N)  \
# 0                 Disposed  Office Trash           42.5               N
# 1                 Recycled           C&D            153               N
# 2                   Reused          NULL           NULL            NULL
# 3                 Recycled          NULL           NULL            NULL
# 4                   Reused          NULL           NULL            NULL
# 5                 Disposed          NULL          34.99               N
# 6                 Disposed          NULL          62.83               N
# 7                 Disposed          NULL         262.95               N
# 8                 Recycled         Wires           1.23               N
# 9                 Recycled     Cardboard         146.67               N
#
#           Location(s) Where Disposed/Recycled/Reused  \
# 0                                      I-66 Landfill
# 1                                   Waste Management
# 2                                               NULL
# 3                                               NULL
# 4                                               NULL
# 5  Federal IPC- Recycle One, 2911 52nd Avenue, Hy...
# 6  Alexandria Waste Recovery Facility,3730 Greent...
# 7  Federal IPC- Recycle One & Alexandria Waste Re...
# 8  Joseph Smith & Sons, 2001 Kenilworth Ave, Capi...
# 9  Federal IPC- Recycle One, 2911 52nd Avenue, Hy...
#
#                                             Filename    Section
# 0                2023 Annual Tonnage Report ACE.json  Section D
# 1                2023 Annual Tonnage Report ACE.json  Section D
# 2                2023 Annual Tonnage Report ACE.json  Section D
# 3      2023 Annual Tonnage Report Chapel Valley.json  Section D
# 4      2023 Annual Tonnage Report Chapel Valley.json  Section D
# 5  2023 Annual Tonnage Report Zero Waste Solution...  Section D
# 6  2023 Annual Tonnage Report Zero Waste Solution...  Section D
# 7  2023 Annual Tonnage Report Zero Waste Solution...  Section D
# 8  2023 Annual Tonnage Report Zero Waste Solution...  Section D
# 9  2023 Annual Tonnage Report Zero Waste Solution...  Section D

# %%
text_columns = [col for col in SectionDTotal.columns if col not in ['Filename', 'Section']]
SectionDTotal_Confidence = SectionDTotal.copy()
for col in text_columns:
    SectionDTotal_Confidence[col + '_confidence'] = SectionDTotal_Confidence.apply(lambda row: calculate_average_confidence(str(row[col]), row['Filename']), axis=1)

# Replacing zeros with hundred
SectionDTotal_Confidence.replace(0, "NULL", inplace=True)

SectionDTotal_Confidence.head()
# Out:
#   Disposed/Recycled/Reused      Material Tons Collected Estimate? (Y/N)  \
# 0                 Disposed  Office Trash           42.5               N
# 1                 Recycled           C&D            153               N
# 2                   Reused          NULL           NULL            NULL
# 3                 Recycled          NULL           NULL            NULL
# 4                   Reused          NULL           NULL            NULL
#
#   Location(s) Where Disposed/Recycled/Reused  \
# 0                              I-66 Landfill
# 1                           Waste Management
# 2                                       NULL
# 3                                       NULL
# 4                                       NULL
#
#                                         Filename    Section  \
# 0            2023 Annual Tonnage Report ACE.json  Section D
# 1            2023 Annual Tonnage Report ACE.json  Section D
# 2            2023 Annual Tonnage Report ACE.json  Section D
# 3  2023 Annual Tonnage Report Chapel Valley.json  Section D
# 4  2023 Annual Tonnage Report Chapel Valley.json  Section D
#
#    Disposed/Recycled/Reused_confidence Material_confidence  \
# 0                                0.995              0.9945
# 1                                0.994               0.993
# 2                                0.994                NULL
# 3                                0.994                NULL
# 4                                0.995                NULL
#
#   Tons Collected_confidence Estimate? (Y/N)_confidence  \
# 0                     0.993                       0.98
# 1                     0.996                       0.98
# 2                      NULL                       NULL
# 3                      NULL                       NULL
# 4                      NULL                       NULL
#
#   Location(s) Where Disposed/Recycled/Reused_confidence
# 0                                              0.887
# 1                                              0.994
# 2                                               NULL
# 3                                               NULL
# 4                                               NULL

# %%
SectionETotal = pd.DataFrame()

# Iterate through each file in the folder
for filename in os.listdir(output_folder_path):
    if filename.endswith(".json"):
        file_path = os.path.join(output_folder_path, filename)
        try:
            with open(file_path, "r") as json_file:
                print(f"-------->Reading {filename}<---------")

                json_data = json.load(json_file)
                documents_list = json_data.get("documents", [])
                for document in documents_list:
                    SectionE = pd.DataFrame()

                    fields_dict = document.get("fields", {})
                    section_e = fields_dict.get("SectionE", {})
                    value_list = section_e.get("value", [])

                    data_list_E = []

                    for item in value_list:
                        field_data_E = {}
                        column1_value = item.get("value", {}).get("COLUMN1", {}).get("value", "")
                        field_data_E["Source Code"] = column1_value

                        # Assuming these keys are present in your JSON structure
                        tons_disposed_value = item.get("value", {}).get("Tons Disposed", {}).get("value", "")
                        field_data_E["Tons Disposed"] = tons_disposed_value

                        estimate_value = item.get("value", {}).get("Estimate? (Y/N)", {}).get("value", "")
                        field_data_E["Estimate? (Y/N)"] = estimate_value

                        facility_value = item.get("value", {}).get("Location(s) Where Disposed", {}).get("value", "")
                        field_data_E["Location(s) Where Disposed"] = facility_value

                        data_list_E.append(field_data_E)
                    
                    # Create DataFrame for SectionE data
                    SectionE = pd.DataFrame(data_list_E)

                    # Data cleaning and transformations
                    SectionE.reset_index(drop=True, inplace=True)
                    SectionE.iloc[:, 1] = SectionE.iloc[:, 1].replace(',', '', regex=True)
                    SectionE = SectionE.map(lambda x: str(x).replace(':selected:', ''))
                    SectionE = SectionE.map(lambda x: str(x).replace('\n', ''))
                    SectionE = SectionE.map(lambda x: str(x).replace('nan', ''))

                    SectionE.iloc[:, 0] = SectionE.iloc[:, 0].replace("", None).ffill()

                    strings_to_check = ['TONS DISPOSED', 'ESTIMATE? (Y/N)', 'LOCATION(S) WHERE DISPOSED']
                    SectionE = SectionE[~(SectionE.iloc[:, 1].str.upper().isin(strings_to_check))]# | SectionB.iloc[:, 2].str.upper().isin(strings_to_check))]
                    SectionE.iloc[:, 0] = SectionE.iloc[:, 0].replace("", None).ffill()

                    # Adding columns
                    SectionE['Filename'] = filename
                    SectionE['Section'] = 'Section E'

                    SectionETotal = pd.concat([SectionETotal, SectionE], ignore_index=True)

        except Exception as e:
            SkippedFiles.append(filename)
            print(f"Skipping file {filename} due to error: {str(e)}")
            continue

SectionETotal = code_strings(SectionETotal, 'Estimate? (Y/N)')
                  
# Removing Materials with Null values
SectionETotal['Tons Disposed'] = SectionETotal['Tons Disposed'].str.replace(r'[^\d. -]', '', regex=True)

SectionETotal = SectionETotal[SectionETotal['Tons Disposed'].isin([0, "0", "o", pd.NA, 'N/A']) == False]
SectionETotal = SectionETotal.replace("", "NULL")
#SectionETotal = SectionETotal.dropna(subset=['Tons Disposed'])

SectionETotal.head(10)
# Out:
# -------->Reading 2023 Annual Tonnage Report ACE.json<---------
# -------->Reading 2023 Annual Tonnage Report Chapel Valley.json<---------
# -------->Reading 2023 Annual Tonnage Report Zero Waste Solutions.json<---------
# -------->Reading 2023 Arlington Annual Tonnage Report-United Rentals.json<---------
# -------->Reading 2023 Arlington Annual Tonnage Report.json<---------
# -------->Reading 2023 Glenayr Apartments Tonnage Report.json<---------
# -------->Reading 2023 Tonnage Report - Bartlett Tree.json<---------
# -------->Reading ADS 2023 Tonnage Report.json<---------
# -------->Reading Atlantic Biofuels Tonnage Report.json<---------
# -------->Reading Capitol Services Tonnage Report 2024 Arlington County.json<---------
# -------->Reading Compost Crew Annual Tonnage Report Arlingon.json<---------
# -------->Reading Concrete Protection and Restoration 2023 Tonnage Report.json<---------
# -------->Reading Darling Ingredients Tonnage Report.json<---------
# -------->Reading Dittmar 2023 Annual Tonnage Report.json<---------
# -------->Reading DMV Hauling Tonnage Report.json<---------
# -------->Reading EAI Arlington Tonnage Report 2024.json<---------
# -------->Reading Environmental Enhancements 2023 Annual Tonnage Report.json<---------
# -------->Reading function enterprises.json<---------
# -------->Reading georgetown paper stock tonnage report.json<---------
# -------->Reading Industrial Disposal Arlington Recycling report 2023.json<---------
# -------->Reading kmG Tonnage Report.json<---------
# -------->Reading Lancaster Landscapes Tonnage Report.json<---------
# Skipping file Lancaster Landscapes Tonnage Report.json due to error: single positional indexer is out-of-bounds
# -------->Reading Lorco Annual Tonnage Report (Signed).json<---------
# -------->Reading Metal Pro Tonnage Report.json<---------
# -------->Reading Olivo 2023 Annual Tonnage Report.json<---------
# -------->Reading Patriot Disposal Arlington County Tonnage Report 2023.json<---------
# -------->Reading Redbox 2023 Annual Tonnage Report (005).json<---------
# -------->Reading Republic Arlington County Recycling & Refuse Tonnage Report CY 2023.json<---------
# -------->Reading RTI 2023 Annual Tonnage Report.json<---------
# -------->Reading Safeguard Shredding Tonnage Report.json<---------
# -------->Reading Safety kleen Systems Tonnage Report.json<---------
# -------->Reading Selective Demolition Tonnage Report.json<---------
# -------->Reading Selective Hauling Tonnage Report.json<---------
# -------->Reading Six Nations 2023 Annual Tonnage Report.json<---------
# -------->Reading Thompson Hauling Tonnage Report.json<---------
# -------->Reading Trash Away Tonnage Report.json<---------
# Skipping file Trash Away Tonnage Report.json due to error: single positional indexer is out-of-bounds
# -------->Reading Washington and Lee Apartments Tonnage Report.json<---------
# -------->Reading Waste Management Arlington 2023 Tonnage Report.json<---------
#                                  Source Code Tons Disposed Estimate? (Y/N)  \
# 0  Residential (Single Family & Multifamily)          NULL            NULL
# 1                                 Commercial            60               Y
# 2                                 Industrial          NULL            NULL
# 3  Residential (Single Family & Multifamily)          NULL            NULL
# 4                                 Commercial          NULL            NULL
# 5                                 Industrial          NULL            NULL
# 6  Residential (Single Family & Multifamily)          NULL            NULL
# 7                                 Commercial       4247.13               N
# 8                                 Industrial          NULL            NULL
# 9  Residential (Single Family & Multifamily)          NULL            NULL
#
#                           Location(s) Where Disposed  \
# 0                                               NULL
# 1                                      I-95 Landfill
# 2                                               NULL
# 3                                               NULL
# 4                                               NULL
# 5                                               NULL
# 6                                               NULL
# 7  Covanta Alexandria/Arlington & Federal IPC- Re...
# 8                                               NULL
# 9                                               NULL
#
#                                             Filename    Section
# 0                2023 Annual Tonnage Report ACE.json  Section E
# 1                2023 Annual Tonnage Report ACE.json  Section E
# 2                2023 Annual Tonnage Report ACE.json  Section E
# 3      2023 Annual Tonnage Report Chapel Valley.json  Section E
# 4      2023 Annual Tonnage Report Chapel Valley.json  Section E
# 5      2023 Annual Tonnage Report Chapel Valley.json  Section E
# 6  2023 Annual Tonnage Report Zero Waste Solution...  Section E
# 7  2023 Annual Tonnage Report Zero Waste Solution...  Section E
# 8  2023 Annual Tonnage Report Zero Waste Solution...  Section E
# 9  2023 Arlington Annual Tonnage Report-United Re...  Section E

# %%
text_columns = [col for col in SectionETotal.columns if col not in ['Filename', 'Section']]
SectionETotal_Confidence = SectionETotal.copy()
for col in text_columns:
    SectionETotal_Confidence[col + '_confidence'] = SectionETotal_Confidence.apply(lambda row: calculate_average_confidence(str(row[col]), row['Filename']), axis=1)

# Replacing zeros with hundred
SectionETotal_Confidence.replace(0, "NULL", inplace=True)

SectionETotal_Confidence.head(100)
# Out:
#                                    Source Code Tons Disposed Estimate? (Y/N)  \
# 0    Residential (Single Family & Multifamily)          NULL            NULL
# 1                                   Commercial            60               Y
# 2                                   Industrial          NULL            NULL
# 3    Residential (Single Family & Multifamily)          NULL            NULL
# 4                                   Commercial          NULL            NULL
# ..                                         ...           ...             ...
# 98                                  Commercial          NULL            NULL
# 99                                  Industrial          NULL            NULL
# 100  Residential (Single Family & Multifamily)          NULL            NULL
# 101                                 Commercial          NULL            NULL
# 102                                 Industrial          NULL            NULL
#
#     Location(s) Where Disposed                                       Filename  \
# 0                         NULL            2023 Annual Tonnage Report ACE.json
# 1                I-95 Landfill            2023 Annual Tonnage Report ACE.json
# 2                         NULL            2023 Annual Tonnage Report ACE.json
# 3                         NULL  2023 Annual Tonnage Report Chapel Valley.json
# 4                         NULL  2023 Annual Tonnage Report Chapel Valley.json
# ..                         ...                                            ...
# 98                        NULL        Safeguard Shredding Tonnage Report.json
# 99                        NULL        Safeguard Shredding Tonnage Report.json
# 100                       NULL       Safety kleen Systems Tonnage Report.json
# 101                       NULL       Safety kleen Systems Tonnage Report.json
# 102                       NULL       Safety kleen Systems Tonnage Report.json
#
#        Section  Source Code_confidence Tons Disposed_confidence  \
# 0    Section E                  0.9866                     NULL
# 1    Section E                  0.9930                    0.997
# 2    Section E                  0.9620                     NULL
# 3    Section E                  0.9762                     NULL
# 4    Section E                  0.9940                     NULL
# ..         ...                     ...                      ...
# 98   Section E                  0.9930                     NULL
# 99   Section E                  0.9920                     NULL
# 100  Section E                  0.9872                     NULL
# 101  Section E                  0.9930                     NULL
# 102  Section E                  0.9610                     NULL
#
#     Estimate? (Y/N)_confidence Location(s) Where Disposed_confidence
# 0                         NULL                                  NULL
# 1                        0.994                                0.8705
# 2                         NULL                                  NULL
# 3                         NULL                                  NULL
# 4                         NULL                                  NULL
# ..                         ...                                   ...
# 98                        NULL                                  NULL
# 99                        NULL                                  NULL
# 100                       NULL                                  NULL
# 101                       NULL                                  NULL
# 102                       NULL                                  NULL
#
# [100 rows x 10 columns]

# %%
data_list_A = []

for filename in os.listdir(output_folder_path):
    if filename.endswith(".json"):
        file = os.path.join(output_folder_path, filename)

        with open(file, "r") as json_file:
            print(f"-------->Reading {filename}<---------")
            json_data = json.load(json_file)

            documents_list = json_data.get("documents", [])

            # Section A
            for idx, document in enumerate(documents_list):
                field_data_A = {}
                for name, field in document.get("fields", {}).items():
                    field_value_A = field.get("valueString", "") if field.get("valueString", "") else field.get("content", "")
                    field_value_confidence = field.get("confidence", "")
                    field_data_A[name] = field_value_A
                    field_data_A[f"{name}_Confidence"] = field_value_confidence
                    field_data_A["Filename"] = filename

                data_list_A.append(field_data_A)

headers_A = [
    'Filename',
    'Company',
    'Company_Confidence',
    'Contact Person',
    'Contact Person_Confidence',
    'Title',
    'Title_Confidence',
    'Address',
    'Address_Confidence',
    'City',
    'City_Confidence',
    'State',
    'State_Confidence',
    'Zip Code',
    'Zip Code_Confidence',
    'Phone',
    'Phone_Confidence',
    'Fax',
    'Fax_Confidence',
    'Email',
    'Email_Confidence',
    'Paper Collection',
    'Paper Collection_Confidence',
    'Electronics Recycling',
    'Electronics Recycling_Confidence',
    'Secure Document Destruction',
    'Secure Document Destruction_Confidence',
    'Tire Recycling',
    'Tire Recycling_Confidence',
    'Solvents/Oil/Antifreeze Recycling',
    'Solvents/Oil/Antifreeze Recycling_Confidence',
    'Metals Recycling (Ferrous & Non-Ferrous)',
    'Metals Recycling (Ferrous & Non-Ferrous)_Confidence',
    'Battery Recycling',
    'Battery Recycling_Confidence',
    'Yard Maintenance/Landscaping',
    'Yard Maintenance/Landscaping_Confidence',
    'Textile, Shoes, and/or Clothing Recycling',
    'Textile, Shoes, and/or Clothing Recycling_Confidence',
    'Commercial Back-Hauling for Cardboard and Other',
    'Commercial Back-Hauling for Cardboard and Other_Confidence',
    'Materials Collection (grocery and other retail outlets)',
    'Materials Collection (grocery and other retail outlets)_Confidence',
    'Solid Waste Collection (trash and recycling)',
    'Solid Waste Collection (trash and recycling)_Confidence',
    'Construction and Demolition Debris Collection',
    'Construction and Demolition Debris Collection_Confidence',
    'Bulk Waste & Junk Collection',
    'Bulk Waste & Junk Collection_Confidence',
    'Material Recovery Facility (MRF)',
    'Material Recovery Facility (MRF)_Confidence',
    'Other',
    'Other_Confidence',
    'Other-Text',
    'Other-Text_Confidence',
    'Printed Signature',
    'Printed Signature_Confidence',
    'Signed Date',
    'Signed Date_Confidence',
    'Methodology',
    'Methodology_Confidence',
    'Comments',
    'Comments_Confidence'
]

df_A_Confidence = pd.DataFrame(data_list_A, columns=headers_A)
df_A_Confidence['Phone'] = df_A_Confidence['Phone'].str.replace(r'[^0-9]', '', regex=True)
df_A_Confidence['City'] = df_A_Confidence['City'].str.replace(r'[^a-zA-Z]', '', regex=True)
df_A_Confidence['Fax'] = df_A_Confidence['Fax'].str.replace(r'[^0-9]', '', regex=True)
df_A_Confidence.replace('', "NULL", inplace =True)
df_A_Confidence.replace(pd.NA, "NULL", inplace=True)

df_A_Confidence.head(10)
# Out:
# -------->Reading 2023 Annual Tonnage Report ACE.json<---------
# -------->Reading 2023 Annual Tonnage Report Chapel Valley.json<---------
# -------->Reading 2023 Annual Tonnage Report Zero Waste Solutions.json<---------
# -------->Reading 2023 Arlington Annual Tonnage Report-United Rentals.json<---------
# -------->Reading 2023 Arlington Annual Tonnage Report.json<---------
# -------->Reading 2023 Glenayr Apartments Tonnage Report.json<---------
# -------->Reading 2023 Tonnage Report - Bartlett Tree.json<---------
# -------->Reading ADS 2023 Tonnage Report.json<---------
# -------->Reading Atlantic Biofuels Tonnage Report.json<---------
# -------->Reading Capitol Services Tonnage Report 2024 Arlington County.json<---------
# -------->Reading Compost Crew Annual Tonnage Report Arlingon.json<---------
# -------->Reading Concrete Protection and Restoration 2023 Tonnage Report.json<---------
# -------->Reading Darling Ingredients Tonnage Report.json<---------
# -------->Reading Dittmar 2023 Annual Tonnage Report.json<---------
# -------->Reading DMV Hauling Tonnage Report.json<---------
# -------->Reading EAI Arlington Tonnage Report 2024.json<---------
# -------->Reading Environmental Enhancements 2023 Annual Tonnage Report.json<---------
# -------->Reading function enterprises.json<---------
# -------->Reading georgetown paper stock tonnage report.json<---------
# -------->Reading Industrial Disposal Arlington Recycling report 2023.json<---------
# -------->Reading kmG Tonnage Report.json<---------
# -------->Reading Lancaster Landscapes Tonnage Report.json<---------
# -------->Reading Lorco Annual Tonnage Report (Signed).json<---------
# -------->Reading Metal Pro Tonnage Report.json<---------
# -------->Reading Olivo 2023 Annual Tonnage Report.json<---------
# -------->Reading Patriot Disposal Arlington County Tonnage Report 2023.json<---------
# -------->Reading Redbox 2023 Annual Tonnage Report (005).json<---------
# -------->Reading Republic Arlington County Recycling & Refuse Tonnage Report CY 2023.json<---------
# -------->Reading RTI 2023 Annual Tonnage Report.json<---------
# -------->Reading Safeguard Shredding Tonnage Report.json<---------
# -------->Reading Safety kleen Systems Tonnage Report.json<---------
# -------->Reading Selective Demolition Tonnage Report.json<---------
# -------->Reading Selective Hauling Tonnage Report.json<---------
# -------->Reading Six Nations 2023 Annual Tonnage Report.json<---------
# -------->Reading Thompson Hauling Tonnage Report.json<---------
# -------->Reading Trash Away Tonnage Report.json<---------
# -------->Reading Washington and Lee Apartments Tonnage Report.json<---------
# -------->Reading Waste Management Arlington 2023 Tonnage Report.json<---------
#                                             Filename  \
# 0                2023 Annual Tonnage Report ACE.json
# 1      2023 Annual Tonnage Report Chapel Valley.json
# 2  2023 Annual Tonnage Report Zero Waste Solution...
# 3  2023 Arlington Annual Tonnage Report-United Re...
# 4          2023 Arlington Annual Tonnage Report.json
# 5        2023 Glenayr Apartments Tonnage Report.json
# 6           2023 Tonnage Report - Bartlett Tree.json
# 7                       ADS 2023 Tonnage Report.json
# 8              Atlantic Biofuels Tonnage Report.json
# 9  Capitol Services Tonnage Report 2024 Arlington...
#
#                                              Company  Company_Confidence  \
# 0                             Ace Deconstruction LLC               0.937
# 1                    Chapel Valley Landscape Company               0.948
# 2                         ZERO WASTE SOLUTIONS, INC.               0.899
# 3  United Rentals (North America), Inc .; DBA Rel...               0.939
# 4               Brandon Rushing Lawn and Garden Care               0.927
# 5                             Glenayr Apartments LLC               0.942
# 6                             BARTLETT TREEE EXPERTS               0.946
# 7                    American Disposal Services Inc.               0.941
# 8                                  Atlantic Biofuels               0.909
# 9                  CAPITOL SERVICES OF VIRGINIA INC.               0.901
#
#     Contact Person  Contact Person_Confidence                        Title  \
# 0     Anchan Ladia                      0.947                          CFO
# 1    JIll Hartkopf                      0.964               Branch Manager
# 2   JESSICA SEXTON                      0.940  ACCOUNTS PAYABLE SPECIALIST
# 3   Jeffrey Walker                      0.957        Environmental Manager
# 4   Tamela Addison                      0.962         Support Team Manager
# 5   Arthur E House                      0.958                        Owner
# 6  MARGOT ARELLANO                      0.957              LEAD ADMIN ASST
# 7       Kyle Byler                      0.953             District Manager
# 8       Matt Lopas                      0.955                     resident
# 9    DAVID J. DUNN                      0.940                    PRESIDENT
#
#    Title_Confidence                       Address  Address_Confidence  \
# 0             0.917       13804 Dawson Beach Road               0.947
# 1             0.949            3041 Colvin Street               0.970
# 2             0.877                  PO BOX 5097,               0.948
# 3             0.948          11825 Livingston Rd,               0.967
# 4             0.938         7805 Cinder Bed Road,               0.686
# 5             0.938  399 N. Park Drive Arlington,               0.914
# 6             0.938     7823 LOISDALE RD, STE LL,               0.948
# 7             0.945         10370 Central Park Dr               0.964
# 8             0.948         2501 W. Lexington St.               0.948
# 9             0.919                  P.O. BOX 279               0.866
#
#           City  City_Confidence State  State_Confidence Zip Code  \
# 0   Woodbridge            0.938    VA             0.940    22191
# 1   Alexandria            0.964    VA             0.948    22314
# 2      CONCORD            0.938    CA             0.949    94524
# 3     Manassas            0.962   VAS             0.955    20109
# 4         NULL            0.414  NULL             0.581     NULL
# 5         NULL            0.482    VA             0.964    22203
# 6  SPRINGFIELD            0.954    VA             0.952    22150
# 7     Manassas            0.964    VA             0.949    20110
# 8    Baltimore            0.948    my             0.953    21223
# 9   SMITHFIELD            0.901   VA.             0.948    23431
#
#    Zip Code_Confidence       Phone  Phone_Confidence          Fax  \
# 0                0.960        NULL             0.918         NULL
# 1                0.971  7035985514             0.942         NULL
# 2                0.964  9252703339             0.918         NULL
# 3                0.970  7036403901             0.948         NULL
# 4                0.488  7033390067             0.943   7036461009
# 5                0.975  7035227354             0.936   7035243805
# 6                0.968  7035506900             0.938  70315502656
# 7                0.970  7033680500             0.943         NULL
# 8                0.963   106084318             0.917         NULL
# 9                0.964  7039985860             0.918   7039986199
#
#    Fax_Confidence                                      Email  \
# 0           0.969               anchan@acedeconstruction.com
# 1           0.968                     jillh@chapelvalley.com
# 2           0.965         ACCOUNTING @ZEROWASTESOLUTIONS.COM
# 3           0.968      environmental@ur.com; jwalker5@ur.com
# 4           0.920                   tammy@brandonrushing.com
# 5           0.916                         glenayrapt@aol.com
# 6           0.792                     MARELLANO@BARTLETT.COM
# 7           0.969                         khuler@adsimal.com
# 8           0.968                  matt@atlanticbiofuelb.net
# 9           0.876  SERVICE @CAPITOL SERVICES OF VIRGINIA.COM
#
#    Email_Confidence Paper Collection  Paper Collection_Confidence  \
# 0             0.965       :selected:                        0.983
# 1             0.982     :unselected:                        0.984
# 2             0.937     :unselected:                        0.983
# 3             0.981     :unselected:                        0.983
# 4             0.979     :unselected:                        0.983
# 5             0.972     :unselected:                        0.984
# 6             0.980     :unselected:                        0.983
# 7             0.981     :unselected:                        0.983
# 8             0.964     :unselected:                        0.983
# 9             0.866     :unselected:                        0.983
#
#   Electronics Recycling  Electronics Recycling_Confidence  \
# 0          :unselected:                             0.983
# 1          :unselected:                             0.983
# 2          :unselected:                             0.983
# 3          :unselected:                             0.983
# 4          :unselected:                             0.983
# 5          :unselected:                             0.984
# 6          :unselected:                             0.984
# 7          :unselected:                             0.983
# 8          :unselected:                             0.983
# 9          :unselected:                             0.983
#
#   Secure Document Destruction  Secure Document Destruction_Confidence  \
# 0                :unselected:                                   0.983
# 1                :unselected:                                   0.983
# 2                :unselected:                                   0.983
# 3                :unselected:                                   0.983
# 4                :unselected:                                   0.983
# 5                :unselected:                                   0.984
# 6                :unselected:                                   0.984
# 7                :unselected:                                   0.983
# 8                :unselected:                                   0.983
# 9                :unselected:                                   0.983
#
#   Tire Recycling  Tire Recycling_Confidence Solvents/Oil/Antifreeze Recycling  \
# 0   :unselected:                      0.985                      :unselected:
# 1   :unselected:                      0.987                      :unselected:
# 2   :unselected:                      0.986                      :unselected:
# 3   :unselected:                      0.986                      :unselected:
# 4   :unselected:                      0.986                      :unselected:
# 5   :unselected:                      0.987                      :unselected:
# 6   :unselected:                      0.987                      :unselected:
# 7   :unselected:                      0.986                      :unselected:
# 8   :unselected:                      0.985                      :unselected:
# 9   :unselected:                      0.985                      :unselected:
#
#    Solvents/Oil/Antifreeze Recycling_Confidence  \
# 0                                         0.983
# 1                                         0.984
# 2                                         0.983
# 3                                         0.983
# 4                                         0.983
# 5                                         0.983
# 6                                         0.983
# 7                                         0.983
# 8                                         0.983
# 9                                         0.983
#
#   Metals Recycling (Ferrous & Non-Ferrous)  \
# 0                               :selected:
# 1                             :unselected:
# 2                             :unselected:
# 3                             :unselected:
# 4                             :unselected:
# 5                             :unselected:
# 6                             :unselected:
# 7                             :unselected:
# 8                             :unselected:
# 9                             :unselected:
#
#    Metals Recycling (Ferrous & Non-Ferrous)_Confidence Battery Recycling  \
# 0                                              0.984          :selected:
# 1                                              0.987        :unselected:
# 2                                              0.986        :unselected:
# 3                                              0.986        :unselected:
# 4                                              0.986        :unselected:
# 5                                              0.987        :unselected:
# 6                                              0.987        :unselected:
# 7                                              0.985        :unselected:
# 8                                              0.985        :unselected:
# 9                                              0.985        :unselected:
#
#    Battery Recycling_Confidence Yard Maintenance/Landscaping  \
# 0                         0.984                 :unselected:
# 1                         0.987                 :unselected:
# 2                         0.986                 :unselected:
# 3                         0.986                 :unselected:
# 4                         0.986                   :selected:
# 5                         0.987                 :unselected:
# 6                         0.987                   :selected:
# 7                         0.985                 :unselected:
# 8                         0.984                 :unselected:
# 9                         0.985                 :unselected:
#
#    Yard Maintenance/Landscaping_Confidence  \
# 0                                    0.983
# 1                                    0.984
# 2                                    0.983
# 3                                    0.983
# 4                                    0.983
# 5                                    0.983
# 6                                    0.983
# 7                                    0.983
# 8                                    0.983
# 9                                    0.983
#
#   Textile, Shoes, and/or Clothing Recycling  \
# 0                              :unselected:
# 1                              :unselected:
# 2                              :unselected:
# 3                              :unselected:
# 4                              :unselected:
# 5                              :unselected:
# 6                              :unselected:
# 7                              :unselected:
# 8                              :unselected:
# 9                              :unselected:
#
#    Textile, Shoes, and/or Clothing Recycling_Confidence  \
# 0                                              0.983
# 1                                              0.984
# 2                                              0.983
# 3                                              0.983
# 4                                              0.983
# 5                                              0.983
# 6                                              0.983
# 7                                              0.983
# 8                                              0.983
# 9                                              0.983
#
#   Commercial Back-Hauling for Cardboard and Other  \
# 0                                      :selected:
# 1                                    :unselected:
# 2                                    :unselected:
# 3                                    :unselected:
# 4                                    :unselected:
# 5                                    :unselected:
# 6                                    :unselected:
# 7                                    :unselected:
# 8                                    :unselected:
# 9                                    :unselected:
#
#    Commercial Back-Hauling for Cardboard and Other_Confidence  \
# 0                                              0.984
# 1                                              0.987
# 2                                              0.986
# 3                                              0.985
# 4                                              0.985
# 5                                              0.987
# 6                                              0.987
# 7                                              0.984
# 8                                              0.984
# 9                                              0.984
#
#   Materials Collection (grocery and other retail outlets)  \
# 0                                       :unselected:
# 1                                       :unselected:
# 2                                       :unselected:
# 3                                       :unselected:
# 4                                       :unselected:
# 5                                       :unselected:
# 6                                       :unselected:
# 7                                       :unselected:
# 8                                       :unselected:
# 9                                       :unselected:
#
#    Materials Collection (grocery and other retail outlets)_Confidence  \
# 0                                              0.983
# 1                                              0.983
# 2                                              0.983
# 3                                              0.983
# 4                                              0.983
# 5                                              0.984
# 6                                              0.984
# 7                                              0.983
# 8                                              0.983
# 9                                              0.983
#
#   Solid Waste Collection (trash and recycling)  \
# 0                                   :selected:
# 1                                   :selected:
# 2                                   :selected:
# 3                                 :unselected:
# 4                                 :unselected:
# 5                                 :unselected:
# 6                                 :unselected:
# 7                                   :selected:
# 8                                 :unselected:
# 9                                   :selected:
#
#    Solid Waste Collection (trash and recycling)_Confidence  \
# 0                                              0.982
# 1                                              0.982
# 2                                              0.982
# 3                                              0.982
# 4                                              0.982
# 5                                              0.983
# 6                                              0.983
# 7                                              0.982
# 8                                              0.982
# 9                                              0.980
#
#   Construction and Demolition Debris Collection  \
# 0                                    :selected:
# 1                                  :unselected:
# 2                                    :selected:
# 3                                  :unselected:
# 4                                  :unselected:
# 5                                  :unselected:
# 6                                  :unselected:
# 7                                    :selected:
# 8                                  :unselected:
# 9                                  :unselected:
#
#    Construction and Demolition Debris Collection_Confidence  \
# 0                                              0.983
# 1                                              0.983
# 2                                              0.983
# 3                                              0.983
# 4                                              0.983
# 5                                              0.984
# 6                                              0.984
# 7                                              0.983
# 8                                              0.983
# 9                                              0.983
#
#   Bulk Waste & Junk Collection  Bulk Waste & Junk Collection_Confidence  \
# 0                 :unselected:                                    0.983
# 1                 :unselected:                                    0.986
# 2                 :unselected:                                    0.984
# 3                 :unselected:                                    0.984
# 4                 :unselected:                                    0.984
# 5                   :selected:                                    0.986
# 6                 :unselected:                                    0.986
# 7                   :selected:                                    0.983
# 8                 :unselected:                                    0.983
# 9                 :unselected:                                    0.983
#
#   Material Recovery Facility (MRF)  \
# 0                     :unselected:
# 1                     :unselected:
# 2                     :unselected:
# 3                     :unselected:
# 4                     :unselected:
# 5                     :unselected:
# 6                     :unselected:
# 7                       :selected:
# 8                     :unselected:
# 9                     :unselected:
#
#    Material Recovery Facility (MRF)_Confidence         Other  \
# 0                                        0.983  :unselected:
# 1                                        0.984  :unselected:
# 2                                        0.983  :unselected:
# 3                                        0.982    :selected:
# 4                                        0.983  :unselected:
# 5                                        0.984  :unselected:
# 6                                        0.984  :unselected:
# 7                                        0.983  :unselected:
# 8                                        0.982    :selected:
# 9                                        0.983  :unselected:
#
#    Other_Confidence                           Other-Text  \
# 0             0.979                                 NULL
# 1             0.981                                 NULL
# 2             0.980                                 NULL
# 3             0.971        Septage/Portable Toilet Waste
# 4             0.980                                 NULL
# 5             0.981                                 NULL
# 6             0.980                                 NULL
# 7             0.979                                 NULL
# 8             0.967  USED Cooking OIL Pickup & REcadilly
# 9             0.973                                 NULL
#
#    Other-Text_Confidence  Printed Signature  Printed Signature_Confidence  \
# 0                  0.972       Anchan Ladia                         0.948
# 1                  0.972      Jill Hartkopf                         0.965
# 2                  0.972     JESSICA SEXTON                         0.937
# 3                  0.884     Jeffrey Walker                         0.965
# 4                  0.972               NULL                         0.843
# 5                  0.972   Deborah J. House                         0.919
# 6                  0.971               NULL                         0.832
# 7                  0.972  Heather Mccracken                         0.955
# 8                  0.878         MATT TOPAS                         0.948
# 9                  0.969      DAVID J. DUNN                         0.919
#
#   Signed Date  Signed Date_Confidence  \
# 0   1/09/2024                   0.944
# 1  01/05/2024                   0.963
# 2   1/31/2024                   0.937
# 3    1/3/2024                   0.962
# 4        NULL                   0.882
# 5    1/3/2024                   0.948
# 6    12/28/25                   0.949
# 7   1/12/2024                   0.951
# 8     1 31/24                   0.863
# 9   1-29-2024                   0.948
#
#                                          Methodology  Methodology_Confidence  \
# 0                                               NULL                   0.989
# 1                                               NULL                   0.989
# 2                                               NULL                   0.988
# 3  We estimate we will collect 200,000 gallons of...                   0.716
# 4  1 bag of debris per client for 40 weeks per ye...                   0.604
# 5                                               NULL                   0.988
# 6  Remington Mulch does not provide tonnage or me...                   0.038
# 7                                               NULL                   0.989
# 8                                                  =                     NaN
# 9  IN ARLINGTON COUNTY AND THE CITY OF ALEXANDRIA...                   0.201
#
#                   Comments  Comments_Confidence
# 0                     NULL                0.989
# 1                     NULL                0.989
# 2                     NULL                0.989
# 3                     NULL                0.989
# 4                     NULL                0.989
# 5  Appliance and Furniture                0.352
# 6                     same                  NaN
# 7                     NULL                0.989
# 8                     NULL                0.962
# 9                     NULL                0.989

# %%
excel_file_path = 'Annual_Tonnage_Sections_WithConfidenceV4.xlsx'
print('Skipped Files:', SkippedFiles)

with pd.ExcelWriter(excel_file_path, engine='openpyxl') as writer:
    df_A.to_excel(writer, sheet_name='SectionA', index=False)
    df_A_Confidence.to_excel(writer, sheet_name='SectionA-Confidence', index=False)
    SectionBTotal.to_excel(writer, sheet_name='SectionB', index=False)
    SectionBTotal_Confidence.to_excel(writer, sheet_name='SectionB-Confidence', index=False)
    SectionCTotal.to_excel(writer, sheet_name='SectionC', index=False)
    SectionCTotal_Confidence.to_excel(writer, sheet_name='SectionC-Confidence', index=False)
    SectionDTotal.to_excel(writer, sheet_name='SectionD', index=False)
    SectionDTotal_Confidence.to_excel(writer, sheet_name='SectionD-Confidence', index=False)
    SectionETotal.to_excel(writer, sheet_name='SectionE', index=False)
    SectionETotal_Confidence.to_excel(writer, sheet_name='SectionE-Confidence', index=False)
    print('done!. Stored as Excel files in:', excel_file_path)
# Out:
# Skipped Files: ['Lancaster Landscapes Tonnage Report.json', 'Lancaster Landscapes Tonnage Report.json', 'Thompson Hauling Tonnage Report.json', 'Lancaster Landscapes Tonnage Report.json', 'Lancaster Landscapes Tonnage Report.json', 'Trash Away Tonnage Report.json']
# done!. Stored as Excel files in: Annual_Tonnage_Sections_WithConfidenceV4.xlsx
